# %% [markdown]
# **Load Data**

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
state_data = pd.read_csv("zecon1/State_time_series.csv",parse_dates=True)
print(len(state_data.columns))
print(len(state_data))
# Out:
# 82
# 13212

# %%
state_data = state_data[['Date','RegionName','ZHVI_1bedroom','ZHVI_2bedroom','ZHVI_3bedroom','ZHVI_4bedroom','ZHVI_BottomTier','ZHVI_CondoCoop','ZHVI_MiddleTier','ZHVI_SingleFamilyResidence','ZHVI_TopTier']]

# %%
state_data["Date"] = pd.to_datetime(state_data["Date"]) 
state_data['Year'] = state_data['Date'].dt.year
state_data['Month'] = state_data['Date'].dt.month

# %%
cross_data = pd.read_csv("zecon1/cities_crosswalk.csv")
#cross_data.head()

# %%
cities_data = pd.read_csv("zecon1/City_time_series.csv")
cities_data.head()
# Out:
#          Date          RegionName  InventorySeasonallyAdjusted_AllHomes  \
# 0  1996-04-30  abbottstownadamspa                                   NaN
# 1  1996-04-30   aberdeenbinghamid                                   NaN
# 2  1996-04-30   aberdeenharfordmd                                   NaN
# 3  1996-04-30    aberdeenmonroems                                   NaN
# 4  1996-04-30     aberdeenmoorenc                                   NaN
#
#    InventoryRaw_AllHomes  MedianListingPricePerSqft_1Bedroom  \
# 0                    NaN                                 NaN
# 1                    NaN                                 NaN
# 2                    NaN                                 NaN
# 3                    NaN                                 NaN
# 4                    NaN                                 NaN
#
#    MedianListingPricePerSqft_2Bedroom  MedianListingPricePerSqft_3Bedroom  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    MedianListingPricePerSqft_4Bedroom  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    MedianListingPricePerSqft_5BedroomOrMore  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    MedianListingPricePerSqft_AllHomes  ...  ZHVI_BottomTier  ZHVI_CondoCoop  \
# 0                                 NaN  ...              NaN             NaN
# 1                                 NaN  ...              NaN             NaN
# 2                                 NaN  ...          81300.0        137900.0
# 3                                 NaN  ...              NaN             NaN
# 4                                 NaN  ...              NaN             NaN
#
#    ZHVI_MiddleTier  ZHVI_SingleFamilyResidence  ZHVI_TopTier  ZRI_AllHomes  \
# 0              NaN                         NaN      108700.0           NaN
# 1              NaN                         NaN      168400.0           NaN
# 2         109600.0                    108600.0      147900.0           NaN
# 3              NaN                         NaN       74500.0           NaN
# 4              NaN                         NaN      131100.0           NaN
#
#    ZRI_AllHomesPlusMultifamily  ZriPerSqft_AllHomes  \
# 0                          NaN                  NaN
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#    Zri_MultiFamilyResidenceRental  Zri_SingleFamilyResidenceRental
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
# [5 rows x 81 columns]

# %%
print(len(cities_data.columns))
print(len(cities_data))
# Out:
# 81
# 3762566

# %%
cities_data["Date"] = pd.to_datetime(cities_data["Date"]) 
cities_data['Year'] = cities_data['Date'].dt.year
cities_data['Month'] = cities_data['Date'].dt.month

# %%
city_state_data = cities_data.join(cross_data.set_index('Unique_City_ID'), on='RegionName')

# %% [markdown]
# **Michigan**

# %%
data_michigan = state_data.loc[state_data['RegionName'] == 'Michigan']

# %%
year_plot = sns.barplot(x="Year", y="ZHVI_MiddleTier", data=data_michigan)
year_plot.set_xticklabels(year_plot.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '1996'),
#  Text(0, 0, '1997'),
#  Text(0, 0, '1998'),
#  Text(0, 0, '1999'),
#  Text(0, 0, '2000'),
#  Text(0, 0, '2001'),
#  Text(0, 0, '2002'),
#  Text(0, 0, '2003'),
#  Text(0, 0, '2004'),
#  Text(0, 0, '2005'),
#  Text(0, 0, '2006'),
#  Text(0, 0, '2007'),
#  Text(0, 0, '2008'),
#  Text(0, 0, '2009'),
#  Text(0, 0, '2010'),
#  Text(0, 0, '2011'),
#  Text(0, 0, '2012'),
#  Text(0, 0, '2013'),
#  Text(0, 0, '2014'),
#  Text(0, 0, '2015'),
#  Text(0, 0, '2016'),
#  Text(0, 0, '2017')]

# %% [markdown]
# This graph shows the median housing price within michigan over the course of the dataset. It accurately shows the 2008 recession and therefore is fairly reasonable to believe.

# %% [markdown]
# **Examining the Country in 2017**

# %%
country_df = state_data[["RegionName","ZHVI_MiddleTier","Year"]]
country_df = country_df.loc[country_df["Year"]==2017]
country_df = country_df.dropna()

# %%
#country_df
state_plot = sns.barplot(x="RegionName", y="ZHVI_MiddleTier", data=country_df)
state_plot.set_xticklabels(state_plot.get_xticklabels(), rotation=90,size=7)
# Out:
# [Text(0, 0, 'Alabama'),
#  Text(0, 0, 'Alaska'),
#  Text(0, 0, 'Arizona'),
#  Text(0, 0, 'Arkansas'),
#  Text(0, 0, 'California'),
#  Text(0, 0, 'Colorado'),
#  Text(0, 0, 'Connecticut'),
#  Text(0, 0, 'Delaware'),
#  Text(0, 0, 'DistrictofColumbia'),
#  Text(0, 0, 'Florida'),
#  Text(0, 0, 'Georgia'),
#  Text(0, 0, 'Hawaii'),
#  Text(0, 0, 'Idaho'),
#  Text(0, 0, 'Illinois'),
#  Text(0, 0, 'Indiana'),
#  Text(0, 0, 'Iowa'),
#  Text(0, 0, 'Kansas'),
#  Text(0, 0, 'Kentucky'),
#  Text(0, 0, 'Maine'),
#  Text(0, 0, 'Maryland'),
#  Text(0, 0, 'Massachusetts'),
#  Text(0, 0, 'Michigan'),
#  Text(0, 0, 'Minnesota'),
#  Text(0, 0, 'Mississippi'),
#  Text(0, 0, 'Missouri'),
#  Text(0, 0, 'Montana'),
#  Text(0, 0, 'Nebraska'),
#  Text(0, 0, 'Nevada'),
#  Text(0, 0, 'NewHampshire'),
#  Text(0, 0, 'NewJersey'),
#  Text(0, 0, 'NewMexico'),
#  Text(0, 0, 'NewYork'),
#  Text(0, 0, 'NorthCarolina'),
#  Text(0, 0, 'NorthDakota'),
#  Text(0, 0, 'Ohio'),
#  Text(0, 0, 'Oklahoma'),
#  Text(0, 0, 'Oregon'),
#  Text(0, 0, 'Pennsylvania'),
#  Text(0, 0, 'RhodeIsland'),
#  Text(0, 0, 'SouthCarolina'),
#  Text(0, 0, 'SouthDakota'),
#  Text(0, 0, 'Tennessee'),
#  Text(0, 0, 'Texas'),
#  Text(0, 0, 'Utah'),
#  Text(0, 0, 'Vermont'),
#  Text(0, 0, 'Virginia'),
#  Text(0, 0, 'Washington'),
#  Text(0, 0, 'WestVirginia'),
#  Text(0, 0, 'Wisconsin'),
#  Text(0, 0, 'Wyoming')]

# %% [markdown]
# This graph makes intuitive sense as the states as the top are Hawaii and California along with Washington D.C. The cheapes states are West Virginia, Mississippi, and Oklahoma.

# %% [markdown]
# **QUESTION ONE:
# I’d like to find out where is the most expensive city to live in 2017 and where
# is the least expensive.**

# %% [markdown]
# Take the values for the state data set prices and determine which are the max and
# min prices overall. I can then visualize these through creating a scatter plot in plot.ly or
# with d3 that maps the max and min for each state’s prices to show the spread and
# differences for each of the states

# %%
max_min_cities = city_state_data
q1_a = max_min_cities[["Date","RegionName","ZHVIPerSqft_AllHomes","ZHVI_BottomTier","ZHVI_MiddleTier","ZHVI_SingleFamilyResidence","ZHVI_TopTier","Month","Year","City","County","State"]]
q1_a = q1_a.dropna()

# %%
#specific data for question
q1_a = q1_a.loc[q1_a['Year'] == 2017]
q1_a = q1_a.loc[q1_a['Month']== 5]
q1_a.head()
# Out:
#               Date              RegionName  ZHVIPerSqft_AllHomes  \
# 3630515 2017-05-31      abbottstownadamspa                 121.0
# 3630518 2017-05-31  aberdeengrays_harborwa                  82.0
# 3630519 2017-05-31       aberdeenharfordmd                 142.0
# 3630523 2017-05-31      abilenedickinsonks                  72.0
# 3630525 2017-05-31       abingdonharfordmd                 151.0
#
#          ZHVI_BottomTier  ZHVI_MiddleTier  ZHVI_SingleFamilyResidence  \
# 3630515         133100.0         143800.0                    143800.0
# 3630518          79100.0         123700.0                    123800.0
# 3630519         144300.0         204100.0                    202500.0
# 3630523          65000.0          96700.0                     96700.0
# 3630525         184400.0         238600.0                    241200.0
#
#          ZHVI_TopTier  Month  Year         City        County State
# 3630515      166700.0      5  2017  Abbottstown         Adams    PA
# 3630518      199200.0      5  2017     Aberdeen  Grays Harbor    WA
# 3630519      298300.0      5  2017     Aberdeen       Harford    MD
# 3630523      146100.0      5  2017      Abilene     Dickinson    KS
# 3630525      317000.0      5  2017     Abingdon       Harford    MD

# %%
q1_a['graph'] = q1_a["City"] + " " + q1_a["State"]

# %%
q1_a_vis = q1_a.sort_values("ton",ascending=False).head(20)
q1_a_vis[["ZHVI_MiddleTier","City","County","State"]]
# Out:
#          ZHVI_MiddleTier             City       County State
# 3631033        6399100.0         Atherton    San Mateo    CA
# 3638742        4421300.0  Los Altos Hills  Santa Clara    CA
# 3636938        4243800.0     Hillsborough    San Mateo    CA
# 3646055        4099600.0       Water Mill      Suffolk    NY
# 3642104        3797800.0   Portola Valley    San Mateo    CA
# 3631519        3562400.0        Belvedere        Marin    CA
# 3646916        3395200.0         Woodside    San Mateo    CA
# 3636873        3183000.0     Hidden Hills  Los Angeles    CA
# 3631662        3042500.0    Beverly Hills  Los Angeles    CA
# 3644200        3020100.0         Stanford  Santa Clara    CA
# 3639005        2892100.0           Malibu  Los Angeles    CA
# 3638743        2891400.0        Los Altos  Santa Clara    CA
# 3639885        2881600.0     Monte Sereno  Santa Clara    CA
# 3641384        2645700.0        Palo Alto  Santa Clara    CA
# 3642330        2594900.0  Rancho Santa Fe    San Diego    CA
# 3647004        2558600.0     Yarrow Point         King    WA
# 3639434        2541700.0           Medina         King    WA
# 3643292        2518200.0         Saratoga  Santa Clara    CA
# 3644754        2507100.0          Tiburon        Marin    CA
# 3633293        2428000.0       Clyde Hill         King    WA

# %%
q1_a_plot = sns.barplot(x="graph", y="ZHVI_MiddleTier", data=q1_a_vis)
q1_a_plot.set_xticklabels(q1_a_plot.get_xticklabels(), rotation=90,size=7)
# Out:
# [Text(0, 0, 'Atherton CA'),
#  Text(0, 0, 'Los Altos Hills CA'),
#  Text(0, 0, 'Hillsborough CA'),
#  Text(0, 0, 'Water Mill NY'),
#  Text(0, 0, 'Portola Valley CA'),
#  Text(0, 0, 'Belvedere CA'),
#  Text(0, 0, 'Woodside CA'),
#  Text(0, 0, 'Hidden Hills CA'),
#  Text(0, 0, 'Beverly Hills CA'),
#  Text(0, 0, 'Stanford CA'),
#  Text(0, 0, 'Malibu CA'),
#  Text(0, 0, 'Los Altos CA'),
#  Text(0, 0, 'Monte Sereno CA'),
#  Text(0, 0, 'Palo Alto CA'),
#  Text(0, 0, 'Rancho Santa Fe CA'),
#  Text(0, 0, 'Yarrow Point WA'),
#  Text(0, 0, 'Medina WA'),
#  Text(0, 0, 'Saratoga CA'),
#  Text(0, 0, 'Tiburon CA'),
#  Text(0, 0, 'Clyde Hill WA')]

# %%
q1_b_vis = q1_a.sort_values("ZHVI_MiddleTier",ascending=False).tail(20)
q1_b_vis[["ZHVI_MiddleTier","City","County","State"]]
# Out:
#          ZHVI_MiddleTier                City       County State
# 3645715          46400.0              Venice      Madison    IL
# 3642349          45700.0              Rankin    Allegheny    PA
# 3640478          45600.0    New Philadelphia   Schuylkill    PA
# 3645984          45500.0              Warren     Trumbull    OH
# 3635049          44400.0          Experiment     Spalding    GA
# 3632854          44300.0         Centreville  Saint Clair    IL
# 3635433          44000.0       Fort McKinley   Montgomery    OH
# 3639752          43300.0         Minersville   Schuylkill    PA
# 3634580          42800.0    East Saint Louis  Saint Clair    IL
# 3632527          42300.0            Campbell     Mahoning    OH
# 3644592          41900.0             Tamaqua   Schuylkill    PA
# 3634178          41400.0             Detroit        Wayne    MI
# 3643602          39800.0  Shenandoah Heights   Schuylkill    PA
# 3633307          38300.0            Coaldale   Schuylkill    PA
# 3643039          37600.0         Saint Clair   Schuylkill    PA
# 3637573          37600.0           Johnstown      Cambria    PA
# 3635895          32900.0         Girardville   Schuylkill    PA
# 3630999          31600.0             Ashland   Schuylkill    PA
# 3643607          31100.0          Shenandoah   Schuylkill    PA
# 3638981          30100.0        Mahanoy City   Schuylkill    PA

# %%
q1_b_plot = sns.barplot(x="graph", y="ZHVI_MiddleTier", data=q1_b_vis)
q1_b_plot.set_xticklabels(q1_b_plot.get_xticklabels(), rotation=90,size=7)
# Out:
# [Text(0, 0, 'Venice IL'),
#  Text(0, 0, 'Rankin PA'),
#  Text(0, 0, 'New Philadelphia PA'),
#  Text(0, 0, 'Warren OH'),
#  Text(0, 0, 'Experiment GA'),
#  Text(0, 0, 'Centreville IL'),
#  Text(0, 0, 'Fort McKinley OH'),
#  Text(0, 0, 'Minersville PA'),
#  Text(0, 0, 'East Saint Louis IL'),
#  Text(0, 0, 'Campbell OH'),
#  Text(0, 0, 'Tamaqua PA'),
#  Text(0, 0, 'Detroit MI'),
#  Text(0, 0, 'Shenandoah Heights PA'),
#  Text(0, 0, 'Coaldale PA'),
#  Text(0, 0, 'Saint Clair PA'),
#  Text(0, 0, 'Johnstown PA'),
#  Text(0, 0, 'Girardville PA'),
#  Text(0, 0, 'Ashland PA'),
#  Text(0, 0, 'Shenandoah PA'),
#  Text(0, 0, 'Mahanoy City PA')]

# %% [markdown]
# **QUESTION 2: Explore each states’ cities and figure out where the most expensive and least
# expensive places to live are for 2017 in each state.**

# %% [markdown]
# Take the values for the city data set and determine which city has the highest price
# per square foot in each state. Then create scatterplot with matplotlib to measure
# each states’ individual cities and show which are the most expensive and least
# expensive parts of the state.

# %%
q2_a = city_state_data.loc[city_state_data['Year'] == 2017]
q2_a = q2_a.loc[q2_a['Month'] == 5]
q2_a = q2_a[["Date","ZHVIPerSqft_AllHomes","Month","Year","City","County","State"]]
q2_a = q2_a.dropna()

# %%
q2_a.head()
# Out:
#               Date  ZHVIPerSqft_AllHomes  Month  Year         City  \
# 3630513 2017-05-31                  92.0      5  2017    Abbeville
# 3630515 2017-05-31                 121.0      5  2017  Abbottstown
# 3630516 2017-05-31                  90.0      5  2017     Aberdeen
# 3630518 2017-05-31                  82.0      5  2017     Aberdeen
# 3630519 2017-05-31                 142.0      5  2017     Aberdeen
#
#                County State
# 3630513     Lafayette    MS
# 3630515         Adams    PA
# 3630516       Bingham    ID
# 3630518  Grays Harbor    WA
# 3630519       Harford    MD

# %%
q2_max = q2_a.groupby(q2_a["State"],sort=False)["ZHVIPerSqft_AllHomes"].transform(max) == q2_a["ZHVIPerSqft_AllHomes"]
q2_a[q2_max]
# Out:
#               Date  ZHVIPerSqft_AllHomes  Month  Year  \
# 3630933 2017-05-31                 463.0      5  2017
# 3631011 2017-05-31                1132.0      5  2017
# 3631033 2017-05-31                1746.0      5  2017
# 3631451 2017-05-31                 363.0      5  2017
# 3631463 2017-05-31                 172.0      5  2017
# 3631707 2017-05-31                 251.0      5  2017
# 3632352 2017-05-31                 200.0      5  2017
# 3632520 2017-05-31                 147.0      5  2017
# 3632944 2017-05-31                 137.0      5  2017
# 3633019 2017-05-31                 647.0      5  2017
# 3633408 2017-05-31                 192.0      5  2017
# 3634333 2017-05-31                 279.0      5  2017
# 3635022 2017-05-31                 166.0      5  2017
# 3635274 2017-05-31                1098.0      5  2017
# 3635520 2017-05-31                 264.0      5  2017
# 3635710 2017-05-31                 210.0      5  2017
# 3635938 2017-05-31                 426.0      5  2017
# 3636293 2017-05-31                 579.0      5  2017
# 3636423 2017-05-31                 704.0      5  2017
# 3637616 2017-05-31                 210.0      5  2017
# 3637706 2017-05-31                 417.0      5  2017
# 3637754 2017-05-31                 388.0      5  2017
# 3637984 2017-05-31                 265.0      5  2017
# 3638509 2017-05-31                 215.0      5  2017
# 3638957 2017-05-31                 110.0      5  2017
# 3639099 2017-05-31                 207.0      5  2017
# 3639434 2017-05-31                 764.0      5  2017
# 3639508 2017-05-31                 175.0      5  2017
# 3639784 2017-05-31                 244.0      5  2017
# 3640113 2017-05-31                 295.0      5  2017
# 3640405 2017-05-31                 426.0      5  2017
# 3640473 2017-05-31                 156.0      5  2017
# 3640498 2017-05-31                 590.0      5  2017
# 3640604 2017-05-31                 171.0      5  2017
# 3641023 2017-05-31                 330.0      5  2017
# 3641134 2017-05-31                 265.0      5  2017
# 3641419 2017-05-31                 377.0      5  2017
# 3642101 2017-05-31                 330.0      5  2017
# 3642301 2017-05-31                 256.0      5  2017
# 3642803 2017-05-31                 414.0      5  2017
# 3643266 2017-05-31                 195.0      5  2017
# 3644306 2017-05-31                 763.0      5  2017
# 3644416 2017-05-31                 606.0      5  2017
# 3644695 2017-05-31                 262.0      5  2017
# 3644830 2017-05-31                 353.0      5  2017
# 3645147 2017-05-31                 781.0      5  2017
# 3645562 2017-05-31                 187.0      5  2017
# 3646033 2017-05-31                 493.0      5  2017
# 3646055 2017-05-31                1185.0      5  2017
# 3646070 2017-05-31                 158.0      5  2017
# 3646964 2017-05-31                 555.0      5  2017
#
#                                City                County State
# 3630933                   Arlington             Arlington    VA
# 3631011                       Aspen                Pitkin    CO
# 3631033                    Atherton             San Mateo    CA
# 3631451                 Belle Meade              Davidson    TN
# 3631463                  Bellefonte            New Castle    DE
# 3631707                  Birmingham               Oakland    MI
# 3632352                  Burlington            Chittenden    VT
# 3632520             Cammack Village               Pulaski    AR
# 3632944                  Cheat Lake            Monongalia    WV
# 3633019         Chevy Chase Village            Montgomery    MD
# 3633408         Colonial Pine Hills            Pennington    SD
# 3634333                 Druid Hills                Dekalb    GA
# 3635022                  Evansville               Natrona    WY
# 3635274               Fisher Island            Miami-Dade    FL
# 3635520                   Frankfort              Franklin    KY
# 3635710            Gallatin Gateway              Gallatin    MT
# 3635938                   Glenbrook               Douglas    NV
# 3636293                   Greenwich             Fairfield    CT
# 3636423                     Haleiwa              Honolulu    HI
# 3637616                      Juneau                Juneau    AK
# 3637706                  Kenilworth                  Cook    IL
# 3637754                     Ketchum                Blaine    ID
# 3637984                       Ladue           Saint Louis    MO
# 3638509                     Lincoln              Burleigh    ND
# 3638957                     Madison               Madison    MS
# 3639099                 Maple Bluff                  Dane    WI
# 3639434                      Medina                  King    WA
# 3639508              Meridian Hills                Marion    IN
# 3639784               Mission Hills               Johnson    KS
# 3640113               Mount Olympus             Salt Lake    UT
# 3640405                  New Castle            Rockingham    NH
# 3640473                 New Orleans               Orleans    LA
# 3640498                New Shoreham            Washington    RI
# 3640604               Nichols Hills              Oklahoma    OK
# 3641023                    Ogunquit                  York    ME
# 3641134                Orange Beach               Baldwin    AL
# 3641419             Paradise Valley              Maricopa    AZ
# 3642101                    Portland             Multnomah    OR
# 3642301                      Radnor              Delaware    PA
# 3642803                 Rollingwood                Travis    TX
# 3643266                    Santa Fe              Santa Fe    NM
# 3644306                Stone Harbor              Cape May    NJ
# 3644416            Sullivans Island            Charleston    SC
# 3644695  The Village of Indian Hill              Hamilton    OH
# 3644830                   Tonka Bay              Hennepin    MN
# 3645147           Town of Nantucket             Nantucket    MA
# 3645562          University Heights               Johnson    IA
# 3646033                  Washington  District of Columbia    DC
# 3646055                  Water Mill               Suffolk    NY
# 3646070                    Waterloo               Douglas    NE
# 3646964          Wrightsville Beach           New Hanover    NC

# %%
max_graph = sns.barplot(x="State", y="ZHVIPerSqft_AllHomes", data=q2_a[q2_max])
max_graph.set_xticklabels(max_graph.get_xticklabels(), rotation=90,size=7)
# Out:
# [Text(0, 0, 'VA'),
#  Text(0, 0, 'CO'),
#  Text(0, 0, 'CA'),
#  Text(0, 0, 'TN'),
#  Text(0, 0, 'DE'),
#  Text(0, 0, 'MI'),
#  Text(0, 0, 'VT'),
#  Text(0, 0, 'AR'),
#  Text(0, 0, 'WV'),
#  Text(0, 0, 'MD'),
#  Text(0, 0, 'SD'),
#  Text(0, 0, 'GA'),
#  Text(0, 0, 'WY'),
#  Text(0, 0, 'FL'),
#  Text(0, 0, 'KY'),
#  Text(0, 0, 'MT'),
#  Text(0, 0, 'NV'),
#  Text(0, 0, 'CT'),
#  Text(0, 0, 'HI'),
#  Text(0, 0, 'AK'),
#  Text(0, 0, 'IL'),
#  Text(0, 0, 'ID'),
#  Text(0, 0, 'MO'),
#  Text(0, 0, 'ND'),
#  Text(0, 0, 'MS'),
#  Text(0, 0, 'WI'),
#  Text(0, 0, 'WA'),
#  Text(0, 0, 'IN'),
#  Text(0, 0, 'KS'),
#  Text(0, 0, 'UT'),
#  Text(0, 0, 'NH'),
#  Text(0, 0, 'LA'),
#  Text(0, 0, 'RI'),
#  Text(0, 0, 'OK'),
#  Text(0, 0, 'ME'),
#  Text(0, 0, 'AL'),
#  Text(0, 0, 'AZ'),
#  Text(0, 0, 'OR'),
#  Text(0, 0, 'PA'),
#  Text(0, 0, 'TX'),
#  Text(0, 0, 'NM'),
#  Text(0, 0, 'NJ'),
#  Text(0, 0, 'SC'),
#  Text(0, 0, 'OH'),
#  Text(0, 0, 'MN'),
#  Text(0, 0, 'MA'),
#  Text(0, 0, 'IA'),
#  Text(0, 0, 'DC'),
#  Text(0, 0, 'NY'),
#  Text(0, 0, 'NE'),
#  Text(0, 0, 'NC')]

# %%
q2_min = q2_a.groupby(q2_a["State"],sort=False)["ZHVIPerSqft_AllHomes"].transform(min) == q2_a["ZHVIPerSqft_AllHomes"]
q2_a[q2_min]
# Out:
#               Date  ZHVIPerSqft_AllHomes  Month  Year                 City  \
# 3631340 2017-05-31                  44.0      5  2017               Bayard
# 3631591 2017-05-31                  43.0      5  2017               Berlin
# 3632027 2017-05-31                  33.0      5  2017         Breckenridge
# 3632101 2017-05-31                  41.0      5  2017             Brighton
# 3632436 2017-05-31                  41.0      5  2017              Cahokia
# 3632779 2017-05-31                  87.0      5  2017           Cedar City
# 3632890 2017-05-31                  36.0      5  2017              Chanute
# 3632938 2017-05-31                  48.0      5  2017        Chattahoochee
# 3633738 2017-05-31                  57.0      5  2017            Creighton
# 3633946 2017-05-31                  56.0      5  2017             Danville
# 3634102 2017-05-31                 121.0      5  2017          Dell Rapids
# 3634275 2017-05-31                  57.0      5  2017              Douglas
# 3634697 2017-05-31                  33.0      5  2017               Edison
# 3635064 2017-05-31                 123.0      5  2017            Fairbanks
# 3635104 2017-05-31                  39.0      5  2017             Fairmont
# 3635682 2017-05-31                  56.0      5  2017              Gaffney
# 3636099 2017-05-31                 109.0      5  2017          Grand Forks
# 3636251 2017-05-31                  38.0      5  2017           Greenfield
# 3636302 2017-05-31                  43.0      5  2017            Greenwood
# 3636319 2017-05-31                  85.0      5  2017             Greybull
# 3636585 2017-05-31                 101.0      5  2017           Harrington
# 3636616 2017-05-31                  39.0      5  2017        Hartford City
# 3636618 2017-05-31                  78.0      5  2017             Hartford
# 3637116 2017-05-31                  70.0      5  2017              Hoquiam
# 3637281 2017-05-31                  78.0      5  2017          Idaho Falls
# 3637539 2017-05-31                  47.0      5  2017             Jennings
# 3638201 2017-05-31                  41.0      5  2017               Lanett
# 3638251 2017-05-31                 103.0      5  2017             Laughlin
# 3638457 2017-05-31                  84.0      5  2017                Libby
# 3638672 2017-05-31                  34.0      5  2017           Lonaconing
# 3638981 2017-05-31                  23.0      5  2017         Mahanoy City
# 3639221 2017-05-31                  48.0      5  2017         Marshalltown
# 3639806 2017-05-31                  81.0      5  2017               Mojave
# 3639900 2017-05-31                  43.0      5  2017           Montevideo
# 3640275 2017-05-31                  45.0      5  2017                Naoma
# 3640339 2017-05-31                  58.0      5  2017              Nekoosa
# 3640658 2017-05-31                  86.0      5  2017          North Adams
# 3640769 2017-05-31                 121.0      5  2017     North Providence
# 3640855 2017-05-31                  56.0      5  2017               Norway
# 3640884 2017-05-31                  76.0      5  2017                Nyssa
# 3641323 2017-05-31                 161.0      5  2017                Pahoa
# 3641765 2017-05-31                  48.0      5  2017           Pine Bluff
# 3642182 2017-05-31                  41.0      5  2017             Prichard
# 3642633 2017-05-31                  35.0      5  2017          River Rouge
# 3642657 2017-05-31                  47.0      5  2017            Riverview
# 3642768 2017-05-31                  57.0      5  2017           Rocky Ford
# 3643131 2017-05-31                  52.0      5  2017                Salem
# 3643139 2017-05-31                  87.0      5  2017               Salina
# 3643199 2017-05-31                  57.0      5  2017           San Manuel
# 3645011 2017-05-31                  30.0      5  2017   Town of Friendship
# 3645060 2017-05-31                  51.0      5  2017      Town of Houlton
# 3645262 2017-05-31                  79.0      5  2017  Town of Springfield
# 3645379 2017-05-31                  43.0      5  2017              Trimont
# 3645822 2017-05-31                  57.0      5  2017               Vivian
# 3646033 2017-05-31                 493.0      5  2017           Washington
# 3646484 2017-05-31                  53.0      5  2017             Westwood
# 3646497 2017-05-31                  35.0      5  2017               Wewoka
# 3646983 2017-05-31                 101.0      5  2017              Wyoming
# 3647038 2017-05-31                  30.0      5  2017           Youngstown
#
#                        County State
# 3631340                 Grant    NM
# 3631591                  Coos    NH
# 3632027              Stephens    TX
# 3632101             Jefferson    AL
# 3632436           Saint Clair    IL
# 3632779                  Iron    UT
# 3632890                Neosho    KS
# 3632938               Gadsden    FL
# 3633738                  Knox    NE
# 3633946         Danville City    VA
# 3634102             Minnehaha    SD
# 3634275               Cochise    AZ
# 3634697               Calhoun    GA
# 3635064  Fairbanks North Star    AK
# 3635104               Robeson    NC
# 3635682              Cherokee    SC
# 3636099           Grand Forks    ND
# 3636251               Weakley    TN
# 3636302               Leflore    MS
# 3636319              Big Horn    WY
# 3636585                  Kent    DE
# 3636616             Blackford    IN
# 3636618              Hartford    CT
# 3637116          Grays Harbor    WA
# 3637281            Bonneville    ID
# 3637539           Saint Louis    MO
# 3638201              Chambers    AL
# 3638251                 Clark    NV
# 3638457               Lincoln    MT
# 3638672              Allegany    MD
# 3638981            Schuylkill    PA
# 3639221              Marshall    IA
# 3639806                  Kern    CA
# 3639900              Chippewa    MN
# 3640275               Raleigh    WV
# 3640339                  Wood    WI
# 3640658             Berkshire    MA
# 3640769            Providence    RI
# 3640855            Orangeburg    SC
# 3640884               Malheur    OR
# 3641323                Hawaii    HI
# 3641765             Jefferson    AR
# 3642182                Mobile    AL
# 3642633                 Wayne    MI
# 3642657           Saint Louis    MO
# 3642768                 Otero    CO
# 3643131                 Salem    NJ
# 3643139                Sevier    UT
# 3643199                 Pinal    AZ
# 3645011              Allegany    NY
# 3645060             Aroostook    ME
# 3645262               Windsor    VT
# 3645379                Martin    MN
# 3645822                 Caddo    LA
# 3646033  District of Columbia    DC
# 3646484                  Boyd    KY
# 3646497              Seminole    OK
# 3646983                  Kent    DE
# 3647038              Mahoning    OH

# %%
#### min_graph = sns.barplot(x="State", y="ZHVIPerSqft_AllHomes", data=q2_a[q2_min])
min_graph.set_xticklabels(min_graph.get_xticklabels(), rotation=90,size=7)

# %% [markdown]
# **QUESTION 3: Determine which cities have the highest overall increase in housing prices over the
# last 10, 5, and 1 year. (Going back from the most current year in the data - 2017)**

# %% [markdown]
# Calculate the difference between square foot price for each city from 2016 – 2017,
# 2012 – 2017, and 2007 – 2017. Which cities have the largest increases? Which have
# the least? Plot a scatter plot in seaborn for each of the time series in question.

# %%
q3 = city_state_data[["Date","RegionName","ZHVIPerSqft_AllHomes","Year","Month","City","County","State"]]
q3 = q3.dropna()
q3.head()
# Out:
#         Date            RegionName  ZHVIPerSqft_AllHomes  Year  Month  \
# 1 1996-04-30     aberdeenbinghamid                  96.0  1996      4
# 2 1996-04-30     aberdeenharfordmd                  76.0  1996      4
# 5 1996-04-30       abernathyhaletx                  48.0  1996      4
# 7 1996-04-30     abingdonharfordmd                  77.0  1996      4
# 9 1996-04-30  abingdonwashingtonva                  57.0  1996      4
#
#         City      County State
# 1   Aberdeen     Bingham    ID
# 2   Aberdeen     Harford    MD
# 5  Abernathy        Hale    TX
# 7   Abingdon     Harford    MD
# 9   Abingdon  Washington    VA

# %%
sqft_2017a = q3.loc[q3['Year']==2017]
sqft_2017 = sqft_2017a.loc[sqft_2017a['Month']==5]
sqft_2016a = q3.loc[q3['Year']==2016]
sqft_2016 = sqft_2016a.loc[sqft_2016a['Month']==5]

# %%
sqft_2017.head()
# Out:
#               Date              RegionName  ZHVIPerSqft_AllHomes  Year  Month  \
# 3630513 2017-05-31    abbevillelafayettems                  92.0  2017      5
# 3630515 2017-05-31      abbottstownadamspa                 121.0  2017      5
# 3630516 2017-05-31       aberdeenbinghamid                  90.0  2017      5
# 3630518 2017-05-31  aberdeengrays_harborwa                  82.0  2017      5
# 3630519 2017-05-31       aberdeenharfordmd                 142.0  2017      5
#
#                 City        County State
# 3630513    Abbeville     Lafayette    MS
# 3630515  Abbottstown         Adams    PA
# 3630516     Aberdeen       Bingham    ID
# 3630518     Aberdeen  Grays Harbor    WA
# 3630519     Aberdeen       Harford    MD

# %%
sqft_2016.head()
# Out:
#               Date              RegionName  ZHVIPerSqft_AllHomes  Year  Month  \
# 3431864 2016-05-31    abbevillelafayettems                  84.0  2016      5
# 3431866 2016-05-31      abbottstownadamspa                 117.0  2016      5
# 3431867 2016-05-31       aberdeenbinghamid                  81.0  2016      5
# 3431869 2016-05-31  aberdeengrays_harborwa                  69.0  2016      5
# 3431870 2016-05-31       aberdeenharfordmd                 138.0  2016      5
#
#                 City        County State
# 3431864    Abbeville     Lafayette    MS
# 3431866  Abbottstown         Adams    PA
# 3431867     Aberdeen       Bingham    ID
# 3431869     Aberdeen  Grays Harbor    WA
# 3431870     Aberdeen       Harford    MD

# %%
#x = sqft_2017.head(200)
#x.sort_values(by="ZHVIPerSqft_AllHomes",ascending=False)

# %%
#sqft_2016.head()
comparison_test = pd.merge(sqft_2017,sqft_2016, on='RegionName')
#comparison_test.head(100)

# %%
comparison_a = pd.merge(sqft_2017,sqft_2016, on='RegionName')
#comparison_a = comparison_a[["RegionName_x","ZHVIPerSqft_AllHomes_x","Year_x","City","State_x","ZHVIPerSqft_AllHomes_y","Year_y"]]
comparison_a['Dif'] = comparison_a["ZHVIPerSqft_AllHomes_x"] - comparison_a["ZHVIPerSqft_AllHomes_y"]

# %%
comparison_a.head()
# Out:
#       Date_x              RegionName  ZHVIPerSqft_AllHomes_x  Year_x  Month_x  \
# 0 2017-05-31    abbevillelafayettems                    92.0    2017        5
# 1 2017-05-31      abbottstownadamspa                   121.0    2017        5
# 2 2017-05-31       aberdeenbinghamid                    90.0    2017        5
# 3 2017-05-31  aberdeengrays_harborwa                    82.0    2017        5
# 4 2017-05-31       aberdeenharfordmd                   142.0    2017        5
#
#         City_x      County_x State_x     Date_y  ZHVIPerSqft_AllHomes_y  \
# 0    Abbeville     Lafayette      MS 2016-05-31                    84.0
# 1  Abbottstown         Adams      PA 2016-05-31                   117.0
# 2     Aberdeen       Bingham      ID 2016-05-31                    81.0
# 3     Aberdeen  Grays Harbor      WA 2016-05-31                    69.0
# 4     Aberdeen       Harford      MD 2016-05-31                   138.0
#
#    Year_y  Month_y       City_y      County_y State_y   Dif
# 0    2016        5    Abbeville     Lafayette      MS   8.0
# 1    2016        5  Abbottstown         Adams      PA   4.0
# 2    2016        5     Aberdeen       Bingham      ID   9.0
# 3    2016        5     Aberdeen  Grays Harbor      WA  13.0
# 4    2016        5     Aberdeen       Harford      MD   4.0

# %%
comparison_a.iloc[comparison_a["Dif"].idxmax()]
# Out:
# Date_x                     2017-05-31 00:00:00
# RegionName                stinson_beachmarinca
# ZHVIPerSqft_AllHomes_x                    1709
# Year_x                                    2017
# Month_x                                      5
# City_x                           Stinson Beach
# County_x                                 Marin
# State_x                                     CA
# Date_y                     2016-05-31 00:00:00
# ZHVIPerSqft_AllHomes_y                    1575
# Year_y                                    2016
# Month_y                                      5
# City_y                           Stinson Beach
# County_y                                 Marin
# State_y                                     CA
# Dif                                        134
# Name: 10096, dtype: object

# %%
comparison_a_graph = comparison_a.sort_values(by=["Dif"],ascending=False)
comparison_a_graph = comparison_a_graph.head(20)
comparison_a_graph
# Out:
#           Date_x                    RegionName  ZHVIPerSqft_AllHomes_x  \
# 10096 2017-05-31          stinson_beachmarinca                  1709.0
# 352   2017-05-31           athertonsan_mateoca                  1746.0
# 11451 2017-05-31           water_millsuffolkny                  1185.0
# 10367 2017-05-31         telluridesan_miguelco                   667.0
# 9892  2017-05-31          southamptonsuffolkny                   744.0
# 1585  2017-05-31      cayucossan_luis_obispoca                   712.0
# 340   2017-05-31                 aspenpitkinco                  1132.0
# 2899  2017-05-31     east_palo_altosan_mateoca                   689.0
# 5966  2017-05-31  los_altos_hillssanta_claraca                  1336.0
# 7954  2017-05-31        palo_altosanta_claraca                  1574.0
# 11144 2017-05-31                   vaileagleco                   631.0
# 4405  2017-05-31              harrisonhudsonnj                   707.0
# 5372  2017-05-31           la_hondasan_mateoca                   718.0
# 11546 2017-05-31             weehawkenhudsonnj                   416.0
# 7572  2017-05-31               noyacksuffolkny                   636.0
# 5581  2017-05-31               larkspurmarinca                   840.0
# 10505 2017-05-31          topangalos_angelesca                   787.0
# 6466  2017-05-31                  medinakingwa                   764.0
# 760   2017-05-31             berkeleyalamedaca                   765.0
# 4960  2017-05-31              invernessmarinca                   726.0
#
#        Year_x  Month_x           City_x         County_x State_x     Date_y  \
# 10096    2017        5    Stinson Beach            Marin      CA 2016-05-31
# 352      2017        5         Atherton        San Mateo      CA 2016-05-31
# 11451    2017        5       Water Mill          Suffolk      NY 2016-05-31
# 10367    2017        5        Telluride       San Miguel      CO 2016-05-31
# 9892     2017        5      Southampton          Suffolk      NY 2016-05-31
# 1585     2017        5          Cayucos  San Luis Obispo      CA 2016-05-31
# 340      2017        5            Aspen           Pitkin      CO 2016-05-31
# 2899     2017        5   East Palo Alto        San Mateo      CA 2016-05-31
# 5966     2017        5  Los Altos Hills      Santa Clara      CA 2016-05-31
# 7954     2017        5        Palo Alto      Santa Clara      CA 2016-05-31
# 11144    2017        5             Vail            Eagle      CO 2016-05-31
# 4405     2017        5         Harrison           Hudson      NJ 2016-05-31
# 5372     2017        5         La Honda        San Mateo      CA 2016-05-31
# 11546    2017        5        Weehawken           Hudson      NJ 2016-05-31
# 7572     2017        5           Noyack          Suffolk      NY 2016-05-31
# 5581     2017        5         Larkspur            Marin      CA 2016-05-31
# 10505    2017        5          Topanga      Los Angeles      CA 2016-05-31
# 6466     2017        5           Medina             King      WA 2016-05-31
# 760      2017        5         Berkeley          Alameda      CA 2016-05-31
# 4960     2017        5        Inverness            Marin      CA 2016-05-31
#
#        ZHVIPerSqft_AllHomes_y  Year_y  Month_y           City_y  \
# 10096                  1575.0    2016        5    Stinson Beach
# 352                    1633.0    2016        5         Atherton
# 11451                  1082.0    2016        5       Water Mill
# 10367                   566.0    2016        5        Telluride
# 9892                    643.0    2016        5      Southampton
# 1585                    612.0    2016        5          Cayucos
# 340                    1039.0    2016        5            Aspen
# 2899                    596.0    2016        5   East Palo Alto
# 5966                   1244.0    2016        5  Los Altos Hills
# 7954                   1485.0    2016        5        Palo Alto
# 11144                   542.0    2016        5             Vail
# 4405                    621.0    2016        5         Harrison
# 5372                    636.0    2016        5         La Honda
# 11546                   335.0    2016        5        Weehawken
# 7572                    556.0    2016        5           Noyack
# 5581                    762.0    2016        5         Larkspur
# 10505                   710.0    2016        5          Topanga
# 6466                    687.0    2016        5           Medina
# 760                     688.0    2016        5         Berkeley
# 4960                    650.0    2016        5        Inverness
#
#               County_y State_y    Dif
# 10096            Marin      CA  134.0
# 352          San Mateo      CA  113.0
# 11451          Suffolk      NY  103.0
# 10367       San Miguel      CO  101.0
# 9892           Suffolk      NY  101.0
# 1585   San Luis Obispo      CA  100.0
# 340             Pitkin      CO   93.0
# 2899         San Mateo      CA   93.0
# 5966       Santa Clara      CA   92.0
# 7954       Santa Clara      CA   89.0
# 11144            Eagle      CO   89.0
# 4405            Hudson      NJ   86.0
# 5372         San Mateo      CA   82.0
# 11546           Hudson      NJ   81.0
# 7572           Suffolk      NY   80.0
# 5581             Marin      CA   78.0
# 10505      Los Angeles      CA   77.0
# 6466              King      WA   77.0
# 760            Alameda      CA   77.0
# 4960             Marin      CA   76.0

# %%
comparison_a_graph.to_csv("comparison_a_graph.csv",encoding='utf-8', index=False)

# %%
sns.lineplot(x="RegionName", y="ZHVIPerSqft_AllHomes_x",data=comparison_a_graph)

# %% [markdown]
# Point of note, I believe that Palo Alto California and Palo Alto Pennsylvania were input wrong in this dataset. I can't be for sure about that but it would make logical sense given the results I am seeing at the top of these lists.

# %%
comparison_a.iloc[comparison_a["Dif"].idxmin()]
# Out:
# Date_x                          2017-05-31 00:00:00
# RegionName                fisher_islandmiami_dadefl
# ZHVIPerSqft_AllHomes_x                         1098
# Year_x                                         2017
# Month_x                                           5
# City_x                                Fisher Island
# County_x                                 Miami-Dade
# State_x                                          FL
# Date_y                          2016-05-31 00:00:00
# ZHVIPerSqft_AllHomes_y                         1183
# Year_y                                         2016
# Month_y                                           5
# City_y                                Fisher Island
# County_y                                 Miami-Dade
# State_y                                          FL
# Dif                                             -85
# Name: 3426, dtype: object

# %%
comparison_a2_graph = comparison_a.sort_values(by=["Dif"],ascending=True)
comparison_a2_graph = comparison_a2_graph.head(20)
comparison_a2_graph
# Out:
#           Date_x                       RegionName  ZHVIPerSqft_AllHomes_x  \
# 3426  2017-05-31        fisher_islandmiami_dadefl                  1098.0
# 9735  2017-05-31         snowmass_villagepitkinco                   634.0
# 8269  2017-05-31              piney_pointharristx                   307.0
# 10845 2017-05-31  town_of_scarboroughcumberlandme                   276.0
# 9909  2017-05-31          southside_placeharristx                   296.0
# 4043  2017-05-31         grand_forksgrand_forksnd                   109.0
# 5249  2017-05-31         key_biscaynemiami_dadefl                   664.0
# 9009  2017-05-31              rooseveltduchesneut                   100.0
# 8558  2017-05-31          prophetstownwhitesideil                    71.0
# 5200  2017-05-31                 kenilworthcookil                   417.0
# 11967 2017-05-31                wiltonmuscatineia                   111.0
# 8587  2017-05-31               put_in_bayottawaoh                   195.0
# 4695  2017-05-31              holdernessgraftonnh                   173.0
# 10537 2017-05-31         town_of_almondalleganyny                    50.0
# 11135 2017-05-31                   uticalickingoh                    70.0
# 6540  2017-05-31                    mettawalakeil                   188.0
# 10182 2017-05-31   sugarcreek_townshiparmstrongpa                    95.0
# 7127  2017-05-31               nehalemtillamookor                   224.0
# 11777 2017-05-31              westportfairfieldct                   402.0
# 9102  2017-05-31               rushfordalleganyny                    65.0
# 10233 2017-05-31    sunny_isles_beachmiami_dadefl                   295.0
#
#        Year_x  Month_x               City_x     County_x State_x     Date_y  \
# 3426     2017        5        Fisher Island   Miami-Dade      FL 2016-05-31
# 9735     2017        5     Snowmass Village       Pitkin      CO 2016-05-31
# 8269     2017        5          Piney Point       Harris      TX 2016-05-31
# 10845    2017        5  Town of Scarborough   Cumberland      ME 2016-05-31
# 9909     2017        5      Southside Place       Harris      TX 2016-05-31
# 4043     2017        5          Grand Forks  Grand Forks      ND 2016-05-31
# 5249     2017        5         Key Biscayne   Miami-Dade      FL 2016-05-31
# 9009     2017        5            Roosevelt     Duchesne      UT 2016-05-31
# 8558     2017        5         Prophetstown    Whiteside      IL 2016-05-31
# 5200     2017        5           Kenilworth         Cook      IL 2016-05-31
# 11967    2017        5               Wilton    Muscatine      IA 2016-05-31
# 8587     2017        5           Put in Bay       Ottawa      OH 2016-05-31
# 4695     2017        5           Holderness      Grafton      NH 2016-05-31
# 10537    2017        5       Town of Almond     Allegany      NY 2016-05-31
# 11135    2017        5                Utica      Licking      OH 2016-05-31
# 6540     2017        5              Mettawa         Lake      IL 2016-05-31
# 10182    2017        5  Sugarcreek Township    Armstrong      PA 2016-05-31
# 7127     2017        5              Nehalem    Tillamook      OR 2016-05-31
# 11777    2017        5             Westport    Fairfield      CT 2016-05-31
# 9102     2017        5             Rushford     Allegany      NY 2016-05-31
# 10233    2017        5    Sunny Isles Beach   Miami-Dade      FL 2016-05-31
#
#        ZHVIPerSqft_AllHomes_y  Year_y  Month_y               City_y  \
# 3426                   1183.0    2016        5        Fisher Island
# 9735                    679.0    2016        5     Snowmass Village
# 8269                    347.0    2016        5          Piney Point
# 10845                   314.0    2016        5  Town of Scarborough
# 9909                    329.0    2016        5      Southside Place
# 4043                    137.0    2016        5          Grand Forks
# 5249                    688.0    2016        5         Key Biscayne
# 9009                    120.0    2016        5            Roosevelt
# 8558                     89.0    2016        5         Prophetstown
# 5200                    435.0    2016        5           Kenilworth
# 11967                   129.0    2016        5               Wilton
# 8587                    213.0    2016        5           Put in Bay
# 4695                    189.0    2016        5           Holderness
# 10537                    65.0    2016        5       Town of Almond
# 11135                    84.0    2016        5                Utica
# 6540                    202.0    2016        5              Mettawa
# 10182                   108.0    2016        5  Sugarcreek Township
# 7127                    237.0    2016        5              Nehalem
# 11777                   415.0    2016        5             Westport
# 9102                     78.0    2016        5             Rushford
# 10233                   307.0    2016        5    Sunny Isles Beach
#
#           County_y State_y   Dif
# 3426    Miami-Dade      FL -85.0
# 9735        Pitkin      CO -45.0
# 8269        Harris      TX -40.0
# 10845   Cumberland      ME -38.0
# 9909        Harris      TX -33.0
# 4043   Grand Forks      ND -28.0
# 5249    Miami-Dade      FL -24.0
# 9009      Duchesne      UT -20.0
# 8558     Whiteside      IL -18.0
# 5200          Cook      IL -18.0
# 11967    Muscatine      IA -18.0
# 8587        Ottawa      OH -18.0
# 4695       Grafton      NH -16.0
# 10537     Allegany      NY -15.0
# 11135      Licking      OH -14.0
# 6540          Lake      IL -14.0
# 10182    Armstrong      PA -13.0
# 7127     Tillamook      OR -13.0
# 11777    Fairfield      CT -13.0
# 9102      Allegany      NY -13.0
# 10233   Miami-Dade      FL -12.0

# %%
comparison_a2_graph.to_csv("comparison_a2_graph.csv",encoding='utf-8', index=False)

# %% [markdown]
# Something peculiar is happening here.  Many of these cities have similar names or seem to be duplicates that are indexed seperately.  I'm not sure what Zillow's reasoning is behind this move.

# %%
sqft_2017b = sqft_2017
sqft_2012a = q3.loc[q3['Year']==2012]
sqft_2012 = sqft_2012a.loc[sqft_2012a['Month']==5]

# %%
comparison_b = pd.merge(sqft_2017b,sqft_2012, on='RegionName')
#comparison_b = comparison_b[["RegionName_x","ZHVIPerSqft_AllHomes_x","Year_x","City","State_x","ZHVIPerSqft_AllHomes_y","Year_y"]]
comparison_b['Dif'] = comparison_b["ZHVIPerSqft_AllHomes_x"] - comparison_b["ZHVIPerSqft_AllHomes_y"]

# %%
#comparison_b.head()

# %%
comparison_b.iloc[comparison_b["Dif"].idxmax()]
# Out:
# Date_x                       2017-05-31 00:00:00
# RegionName                palo_altosanta_claraca
# ZHVIPerSqft_AllHomes_x                      1574
# Year_x                                      2017
# Month_x                                        5
# City_x                                 Palo Alto
# County_x                             Santa Clara
# State_x                                       CA
# Date_y                       2012-05-31 00:00:00
# ZHVIPerSqft_AllHomes_y                       801
# Year_y                                      2012
# Month_y                                        5
# City_y                                 Palo Alto
# County_y                             Santa Clara
# State_y                                       CA
# Dif                                          773
# Name: 7859, dtype: object

# %%
comparison_b_graph = comparison_b.sort_values(by=["Dif"],ascending=False)
comparison_b_graph = comparison_b_graph.head(20)
comparison_b_graph
# Out:
#           Date_x                         RegionName  ZHVIPerSqft_AllHomes_x  \
# 7859  2017-05-31             palo_altosanta_claraca                  1574.0
# 349   2017-05-31                athertonsan_mateoca                  1746.0
# 9980  2017-05-31               stinson_beachmarinca                  1709.0
# 9919  2017-05-31              stanfordsanta_claraca                  1286.0
# 5896  2017-05-31             los_altossanta_claraca                  1271.0
# 5895  2017-05-31       los_altos_hillssanta_claraca                  1336.0
# 11973 2017-05-31                woodsidesan_mateoca                  1375.0
# 8386  2017-05-31          portola_valleysan_mateoca                  1376.0
# 6428  2017-05-31              menlo_parksan_mateoca                  1175.0
# 6920  2017-05-31         mountain_viewsanta_claraca                   995.0
# 4604  2017-05-31            hillsboroughsan_mateoca                  1224.0
# 10120 2017-05-31             sunnyvalesanta_claraca                   940.0
# 7338  2017-05-31         north_fair_oakssan_mateoca                   821.0
# 817   2017-05-31         beverly_hillslos_angelesca                  1140.0
# 2868  2017-05-31          east_palo_altosan_mateoca                   689.0
# 713   2017-05-31                   belvederemarinca                  1333.0
# 6124  2017-05-31       manhattan_beachlos_angelesca                  1039.0
# 2364  2017-05-31             cupertinosanta_claraca                  1009.0
# 4582  2017-05-31  highlands_baywood_parksan_mateoca                   963.0
# 9040  2017-05-31                sag_harborsuffolkny                  1029.0
#
#        Year_x  Month_x                  City_x     County_x State_x  \
# 7859     2017        5               Palo Alto  Santa Clara      CA
# 349      2017        5                Atherton    San Mateo      CA
# 9980     2017        5           Stinson Beach        Marin      CA
# 9919     2017        5                Stanford  Santa Clara      CA
# 5896     2017        5               Los Altos  Santa Clara      CA
# 5895     2017        5         Los Altos Hills  Santa Clara      CA
# 11973    2017        5                Woodside    San Mateo      CA
# 8386     2017        5          Portola Valley    San Mateo      CA
# 6428     2017        5              Menlo Park    San Mateo      CA
# 6920     2017        5           Mountain View  Santa Clara      CA
# 4604     2017        5            Hillsborough    San Mateo      CA
# 10120    2017        5               Sunnyvale  Santa Clara      CA
# 7338     2017        5         North Fair Oaks    San Mateo      CA
# 817      2017        5           Beverly Hills  Los Angeles      CA
# 2868     2017        5          East Palo Alto    San Mateo      CA
# 713      2017        5               Belvedere        Marin      CA
# 6124     2017        5         Manhattan Beach  Los Angeles      CA
# 2364     2017        5               Cupertino  Santa Clara      CA
# 4582     2017        5  Highlands-Baywood Park    San Mateo      CA
# 9040     2017        5              Sag Harbor      Suffolk      NY
#
#           Date_y  ZHVIPerSqft_AllHomes_y  Year_y  Month_y  \
# 7859  2012-05-31                   801.0    2012        5
# 349   2012-05-31                   977.0    2012        5
# 9980  2012-05-31                  1040.0    2012        5
# 9919  2012-05-31                   715.0    2012        5
# 5896  2012-05-31                   724.0    2012        5
# 5895  2012-05-31                   797.0    2012        5
# 11973 2012-05-31                   838.0    2012        5
# 8386  2012-05-31                   864.0    2012        5
# 6428  2012-05-31                   681.0    2012        5
# 6920  2012-05-31                   501.0    2012        5
# 4604  2012-05-31                   745.0    2012        5
# 10120 2012-05-31                   466.0    2012        5
# 7338  2012-05-31                   354.0    2012        5
# 817   2012-05-31                   677.0    2012        5
# 2868  2012-05-31                   250.0    2012        5
# 713   2012-05-31                   896.0    2012        5
# 6124  2012-05-31                   605.0    2012        5
# 2364  2012-05-31                   576.0    2012        5
# 4582  2012-05-31                   533.0    2012        5
# 9040  2012-05-31                   604.0    2012        5
#
#                        City_y     County_y State_y    Dif
# 7859                Palo Alto  Santa Clara      CA  773.0
# 349                  Atherton    San Mateo      CA  769.0
# 9980            Stinson Beach        Marin      CA  669.0
# 9919                 Stanford  Santa Clara      CA  571.0
# 5896                Los Altos  Santa Clara      CA  547.0
# 5895          Los Altos Hills  Santa Clara      CA  539.0
# 11973                Woodside    San Mateo      CA  537.0
# 8386           Portola Valley    San Mateo      CA  512.0
# 6428               Menlo Park    San Mateo      CA  494.0
# 6920            Mountain View  Santa Clara      CA  494.0
# 4604             Hillsborough    San Mateo      CA  479.0
# 10120               Sunnyvale  Santa Clara      CA  474.0
# 7338          North Fair Oaks    San Mateo      CA  467.0
# 817             Beverly Hills  Los Angeles      CA  463.0
# 2868           East Palo Alto    San Mateo      CA  439.0
# 713                 Belvedere        Marin      CA  437.0
# 6124          Manhattan Beach  Los Angeles      CA  434.0
# 2364                Cupertino  Santa Clara      CA  433.0
# 4582   Highlands-Baywood Park    San Mateo      CA  430.0
# 9040               Sag Harbor      Suffolk      NY  425.0

# %%
comparison_b_graph.to_csv("comparison_b_graph.csv",encoding='utf-8', index=False)

# %%
comparison_b2_graph = comparison_b.sort_values(by=["Dif"],ascending=True)
comparison_b2_graph = comparison_b2_graph.head(20)
comparison_b2_graph
# Out:
#           Date_x              RegionName  ZHVIPerSqft_AllHomes_x  Year_x  \
# 8903  2017-05-31     rooseveltduchesneut                   100.0    2017
# 9792  2017-05-31      southportlincolnme                   302.0    2017
# 11102 2017-05-31       versaillesdarkeoh                    83.0    2017
# 4121  2017-05-31       greenvilledarkeoh                    69.0    2017
# 2606  2017-05-31        dickinsonstarknd                   172.0    2017
# 258   2017-05-31          arcanumdarkeoh                    70.0    2017
# 11080 2017-05-31  ventnor_cityatlanticnj                   164.0    2017
# 5747  2017-05-31       linwooddelawarepa                    64.0    2017
# 3707  2017-05-31      galenajo_daviessil                    90.0    2017
# 5090  2017-05-31      kankakeekankakeeil                    58.0    2017
# 1027  2017-05-31       bradleykankakeeil                    80.0    2017
# 910   2017-05-31   blue_earthfaribaultmn                    91.0    2017
# 5973  2017-05-31        lumbertonlamarms                    59.0    2017
# 8347  2017-05-31    port_isabelcamerontx                   137.0    2017
# 201   2017-05-31        andrewsandrewstx                    96.0    2017
# 9073  2017-05-31     saint_henrymerceroh                   104.0    2017
# 11023 2017-05-31      vails_gateorangeny                   133.0    2017
# 5745  2017-05-31       linwoodatlanticnj                   121.0    2017
# 2191  2017-05-31      corollacurritucknc                   185.0    2017
# 10811 2017-05-31       trainerdelawarepa                    71.0    2017
#
#        Month_x        City_x    County_x State_x     Date_y  \
# 8903         5     Roosevelt    Duchesne      UT 2012-05-31
# 9792         5     Southport     Lincoln      ME 2012-05-31
# 11102        5    Versailles       Darke      OH 2012-05-31
# 4121         5    Greenville       Darke      OH 2012-05-31
# 2606         5     Dickinson       Stark      ND 2012-05-31
# 258          5       Arcanum       Darke      OH 2012-05-31
# 11080        5  Ventnor City    Atlantic      NJ 2012-05-31
# 5747         5       Linwood    Delaware      PA 2012-05-31
# 3707         5        Galena  Jo Daviess      IL 2012-05-31
# 5090         5      Kankakee    Kankakee      IL 2012-05-31
# 1027         5       Bradley    Kankakee      IL 2012-05-31
# 910          5    Blue Earth   Faribault      MN 2012-05-31
# 5973         5     Lumberton       Lamar      MS 2012-05-31
# 8347         5   Port Isabel     Cameron      TX 2012-05-31
# 201          5       Andrews     Andrews      TX 2012-05-31
# 9073         5   Saint Henry      Mercer      OH 2012-05-31
# 11023        5    Vails Gate      Orange      NY 2012-05-31
# 5745         5       Linwood    Atlantic      NJ 2012-05-31
# 2191         5       Corolla   Currituck      NC 2012-05-31
# 10811        5       Trainer    Delaware      PA 2012-05-31
#
#        ZHVIPerSqft_AllHomes_y  Year_y  Month_y        City_y    County_y  \
# 8903                    160.0    2012        5     Roosevelt    Duchesne
# 9792                    331.0    2012        5     Southport     Lincoln
# 11102                   106.0    2012        5    Versailles       Darke
# 4121                     90.0    2012        5    Greenville       Darke
# 2606                    193.0    2012        5     Dickinson       Stark
# 258                      90.0    2012        5       Arcanum       Darke
# 11080                   181.0    2012        5  Ventnor City    Atlantic
# 5747                     79.0    2012        5       Linwood    Delaware
# 3707                    104.0    2012        5        Galena  Jo Daviess
# 5090                     72.0    2012        5      Kankakee    Kankakee
# 1027                     93.0    2012        5       Bradley    Kankakee
# 910                     104.0    2012        5    Blue Earth   Faribault
# 5973                     72.0    2012        5     Lumberton       Lamar
# 8347                    150.0    2012        5   Port Isabel     Cameron
# 201                     109.0    2012        5       Andrews     Andrews
# 9073                    116.0    2012        5   Saint Henry      Mercer
# 11023                   145.0    2012        5    Vails Gate      Orange
# 5745                    133.0    2012        5       Linwood    Atlantic
# 2191                    197.0    2012        5       Corolla   Currituck
# 10811                    82.0    2012        5       Trainer    Delaware
#
#       State_y   Dif
# 8903       UT -60.0
# 9792       ME -29.0
# 11102      OH -23.0
# 4121       OH -21.0
# 2606       ND -21.0
# 258        OH -20.0
# 11080      NJ -17.0
# 5747       PA -15.0
# 3707       IL -14.0
# 5090       IL -14.0
# 1027       IL -13.0
# 910        MN -13.0
# 5973       MS -13.0
# 8347       TX -13.0
# 201        TX -13.0
# 9073       OH -12.0
# 11023      NY -12.0
# 5745       NJ -12.0
# 2191       NC -12.0
# 10811      PA -11.0

# %%
comparison_b2_graph.to_csv("comparison_b2_graph.csv",encoding='utf-8', index=False)

# %% [markdown]
# Many of these cities are similar to the losts above which makes sense considering the time series in question.

# %%
sqft_2017c = sqft_2017
sqft_2007a = q3.loc[q3['Year']==2007]
sqft_2007 = sqft_2007a.loc[sqft_2007a['Month']==5]

# %%
comparison_c = pd.merge(sqft_2017c,sqft_2007, on='RegionName')
#comparison_c = comparison_c[["RegionName_x","ZHVIPerSqft_AllHomes_x","Year_x","City","State_x","ZHVIPerSqft_AllHomes_y","Year_y"]]
comparison_c['Dif'] = comparison_c["ZHVIPerSqft_AllHomes_x"] - comparison_c["ZHVIPerSqft_AllHomes_y"]

# %%
comparison_c.iloc[comparison_c["Dif"].idxmax()]
# Out:
# Date_x                       2017-05-31 00:00:00
# RegionName                palo_altosanta_claraca
# ZHVIPerSqft_AllHomes_x                      1574
# Year_x                                      2017
# Month_x                                        5
# City_x                                 Palo Alto
# County_x                             Santa Clara
# State_x                                       CA
# Date_y                       2007-05-31 00:00:00
# ZHVIPerSqft_AllHomes_y                       753
# Year_y                                      2007
# Month_y                                        5
# City_y                                 Palo Alto
# County_y                             Santa Clara
# State_y                                       CA
# Dif                                          821
# Name: 7262, dtype: object

# %%
comparison_c_graph = comparison_c.sort_values(by=["Dif"],ascending=False)
comparison_c_graph = comparison_c_graph.head(20)
comparison_c_graph
# Out:
#           Date_x                         RegionName  ZHVIPerSqft_AllHomes_x  \
# 7262  2017-05-31             palo_altosanta_claraca                  1574.0
# 320   2017-05-31                athertonsan_mateoca                  1746.0
# 9242  2017-05-31               stinson_beachmarinca                  1709.0
# 5440  2017-05-31             los_altossanta_claraca                  1271.0
# 9185  2017-05-31              stanfordsanta_claraca                  1286.0
# 5439  2017-05-31       los_altos_hillssanta_claraca                  1336.0
# 6386  2017-05-31         mountain_viewsanta_claraca                   995.0
# 5925  2017-05-31              menlo_parksan_mateoca                  1175.0
# 11098 2017-05-31                woodsidesan_mateoca                  1375.0
# 2169  2017-05-31             cupertinosanta_claraca                  1009.0
# 4218  2017-05-31  highlands_baywood_parksan_mateoca                   963.0
# 9370  2017-05-31             sunnyvalesanta_claraca                   940.0
# 1164  2017-05-31              burlingamesan_mateoca                  1034.0
# 7754  2017-05-31          portola_valleysan_mateoca                  1376.0
# 8359  2017-05-31                sag_harborsuffolkny                  1029.0
# 650   2017-05-31                   belvederemarinca                  1333.0
# 642   2017-05-31                 belmontsan_mateoca                   907.0
# 8564  2017-05-31              saratogasanta_claraca                  1025.0
# 741   2017-05-31         beverly_hillslos_angelesca                  1140.0
# 8471  2017-05-31              san_carlossan_mateoca                   929.0
#
#        Year_x  Month_x                  City_x     County_x State_x  \
# 7262     2017        5               Palo Alto  Santa Clara      CA
# 320      2017        5                Atherton    San Mateo      CA
# 9242     2017        5           Stinson Beach        Marin      CA
# 5440     2017        5               Los Altos  Santa Clara      CA
# 9185     2017        5                Stanford  Santa Clara      CA
# 5439     2017        5         Los Altos Hills  Santa Clara      CA
# 6386     2017        5           Mountain View  Santa Clara      CA
# 5925     2017        5              Menlo Park    San Mateo      CA
# 11098    2017        5                Woodside    San Mateo      CA
# 2169     2017        5               Cupertino  Santa Clara      CA
# 4218     2017        5  Highlands-Baywood Park    San Mateo      CA
# 9370     2017        5               Sunnyvale  Santa Clara      CA
# 1164     2017        5              Burlingame    San Mateo      CA
# 7754     2017        5          Portola Valley    San Mateo      CA
# 8359     2017        5              Sag Harbor      Suffolk      NY
# 650      2017        5               Belvedere        Marin      CA
# 642      2017        5                 Belmont    San Mateo      CA
# 8564     2017        5                Saratoga  Santa Clara      CA
# 741      2017        5           Beverly Hills  Los Angeles      CA
# 8471     2017        5              San Carlos    San Mateo      CA
#
#           Date_y  ZHVIPerSqft_AllHomes_y  Year_y  Month_y  \
# 7262  2007-05-31                   753.0    2007        5
# 320   2007-05-31                  1058.0    2007        5
# 9242  2007-05-31                  1060.0    2007        5
# 5440  2007-05-31                   725.0    2007        5
# 9185  2007-05-31                   751.0    2007        5
# 5439  2007-05-31                   871.0    2007        5
# 6386  2007-05-31                   546.0    2007        5
# 5925  2007-05-31                   728.0    2007        5
# 11098 2007-05-31                   958.0    2007        5
# 2169  2007-05-31                   594.0    2007        5
# 4218  2007-05-31                   550.0    2007        5
# 9370  2007-05-31                   534.0    2007        5
# 1164  2007-05-31                   640.0    2007        5
# 7754  2007-05-31                   987.0    2007        5
# 8359  2007-05-31                   647.0    2007        5
# 650   2007-05-31                   958.0    2007        5
# 642   2007-05-31                   537.0    2007        5
# 8564  2007-05-31                   680.0    2007        5
# 741   2007-05-31                   797.0    2007        5
# 8471  2007-05-31                   594.0    2007        5
#
#                        City_y     County_y State_y    Dif
# 7262                Palo Alto  Santa Clara      CA  821.0
# 320                  Atherton    San Mateo      CA  688.0
# 9242            Stinson Beach        Marin      CA  649.0
# 5440                Los Altos  Santa Clara      CA  546.0
# 9185                 Stanford  Santa Clara      CA  535.0
# 5439          Los Altos Hills  Santa Clara      CA  465.0
# 6386            Mountain View  Santa Clara      CA  449.0
# 5925               Menlo Park    San Mateo      CA  447.0
# 11098                Woodside    San Mateo      CA  417.0
# 2169                Cupertino  Santa Clara      CA  415.0
# 4218   Highlands-Baywood Park    San Mateo      CA  413.0
# 9370                Sunnyvale  Santa Clara      CA  406.0
# 1164               Burlingame    San Mateo      CA  394.0
# 7754           Portola Valley    San Mateo      CA  389.0
# 8359               Sag Harbor      Suffolk      NY  382.0
# 650                 Belvedere        Marin      CA  375.0
# 642                   Belmont    San Mateo      CA  370.0
# 8564                 Saratoga  Santa Clara      CA  345.0
# 741             Beverly Hills  Los Angeles      CA  343.0
# 8471               San Carlos    San Mateo      CA  335.0

# %%
comparison_c_graph.to_csv("comparison_c_graph.csv",encoding='utf-8', index=False)

# %%
comparison_c2_graph = comparison_c.sort_values(by=["Dif"],ascending=True)
comparison_c2_graph = comparison_c2_graph.head(21)
comparison_c2_graph
# Out:
#           Date_x                       RegionName  ZHVIPerSqft_AllHomes_x  \
# 4844  2017-05-31                 kirkwoodalpineca                   283.0
# 11130 2017-05-31  wrightsville_beachnew_hanovernc                   555.0
# 4678  2017-05-31           jupiter_islandmartinfl                   923.0
# 940   2017-05-31         bradleysan_luis_obispoca                   246.0
# 2741  2017-05-31           edisto_beachcolletonsc                   221.0
# 4491  2017-05-31           indian_beachcarteretnc                   221.0
# 326   2017-05-31         atlantic_beachcarteretnc                   205.0
# 5630  2017-05-31              mammoth_lakesmonoca                   296.0
# 10797 2017-05-31                 westwoodplumasca                   167.0
# 6988  2017-05-31      ocean_isle_beachbrunswicknc                   193.0
# 7538  2017-05-31      pine_knoll_shorescarteretnc                   196.0
# 2018  2017-05-31               corollacurritucknc                   185.0
# 7134  2017-05-31              ortley_beachoceannj                   285.0
# 2099  2017-05-31      crescent_beachsaint_johnsfl                   279.0
# 1014  2017-05-31             brigantineatlanticnj                   203.0
# 8241  2017-05-31                 roselandnelsonva                   142.0
# 3347  2017-05-31              freedomsanta_cruzca                   356.0
# 8657  2017-05-31                seasidemontereyca                   393.0
# 2869  2017-05-31           emerald_islecarteretnc                   232.0
# 5415  2017-05-31               longportatlanticnj                   467.0
# 1607  2017-05-31                  chesterplumasca                   155.0
#
#        Year_x  Month_x              City_x         County_x State_x  \
# 4844     2017        5            Kirkwood           Alpine      CA
# 11130    2017        5  Wrightsville Beach      New Hanover      NC
# 4678     2017        5      Jupiter Island           Martin      FL
# 940      2017        5             Bradley  San Luis Obispo      CA
# 2741     2017        5        Edisto Beach         Colleton      SC
# 4491     2017        5        Indian Beach         Carteret      NC
# 326      2017        5      Atlantic Beach         Carteret      NC
# 5630     2017        5       Mammoth Lakes             Mono      CA
# 10797    2017        5            Westwood           Plumas      CA
# 6988     2017        5    Ocean Isle Beach        Brunswick      NC
# 7538     2017        5   Pine Knoll Shores         Carteret      NC
# 2018     2017        5             Corolla        Currituck      NC
# 7134     2017        5        Ortley Beach            Ocean      NJ
# 2099     2017        5      Crescent Beach      Saint Johns      FL
# 1014     2017        5          Brigantine         Atlantic      NJ
# 8241     2017        5            Roseland           Nelson      VA
# 3347     2017        5             Freedom       Santa Cruz      CA
# 8657     2017        5             Seaside         Monterey      CA
# 2869     2017        5        Emerald Isle         Carteret      NC
# 5415     2017        5            Longport         Atlantic      NJ
# 1607     2017        5             Chester           Plumas      CA
#
#           Date_y  ZHVIPerSqft_AllHomes_y  Year_y  Month_y              City_y  \
# 4844  2007-05-31                   528.0    2007        5            Kirkwood
# 11130 2007-05-31                   758.0    2007        5  Wrightsville Beach
# 4678  2007-05-31                  1114.0    2007        5      Jupiter Island
# 940   2007-05-31                   426.0    2007        5             Bradley
# 2741  2007-05-31                   391.0    2007        5        Edisto Beach
# 4491  2007-05-31                   389.0    2007        5        Indian Beach
# 326   2007-05-31                   371.0    2007        5      Atlantic Beach
# 5630  2007-05-31                   447.0    2007        5       Mammoth Lakes
# 10797 2007-05-31                   316.0    2007        5            Westwood
# 6988  2007-05-31                   338.0    2007        5    Ocean Isle Beach
# 7538  2007-05-31                   336.0    2007        5   Pine Knoll Shores
# 2018  2007-05-31                   323.0    2007        5             Corolla
# 7134  2007-05-31                   419.0    2007        5        Ortley Beach
# 2099  2007-05-31                   411.0    2007        5      Crescent Beach
# 1014  2007-05-31                   335.0    2007        5          Brigantine
# 8241  2007-05-31                   265.0    2007        5            Roseland
# 3347  2007-05-31                   478.0    2007        5             Freedom
# 8657  2007-05-31                   513.0    2007        5             Seaside
# 2869  2007-05-31                   350.0    2007        5        Emerald Isle
# 5415  2007-05-31                   585.0    2007        5            Longport
# 1607  2007-05-31                   272.0    2007        5             Chester
#
#               County_y State_y    Dif
# 4844            Alpine      CA -245.0
# 11130      New Hanover      NC -203.0
# 4678            Martin      FL -191.0
# 940    San Luis Obispo      CA -180.0
# 2741          Colleton      SC -170.0
# 4491          Carteret      NC -168.0
# 326           Carteret      NC -166.0
# 5630              Mono      CA -151.0
# 10797           Plumas      CA -149.0
# 6988         Brunswick      NC -145.0
# 7538          Carteret      NC -140.0
# 2018         Currituck      NC -138.0
# 7134             Ocean      NJ -134.0
# 2099       Saint Johns      FL -132.0
# 1014          Atlantic      NJ -132.0
# 8241            Nelson      VA -123.0
# 3347        Santa Cruz      CA -122.0
# 8657          Monterey      CA -120.0
# 2869          Carteret      NC -118.0
# 5415          Atlantic      NJ -118.0
# 1607            Plumas      CA -117.0

# %%
sns.scatterplot(y="Dif", x="City_y", data=comparison_c2_graph)

# %%
comparison_c2_graph.to_csv("comparison_c2_graph.csv",encoding='utf-8', index=False)

# %% [markdown]
# **QUESTION 4: For a city of choice, (most likely Ann Arbor) have prices for each size of home
# changed in similar amounts over the course of the datasets recordings or are there
# some sizes that are more affordable or less affordable within the city?**

# %% [markdown]
# Calculate the mean increase for each type of home (1 bedroom, 2 bedroom, etc.) in
# Ann Arbor. Calculate the average price change for each of these types of homes
# year to year. Compare the average price change, is it similar or different? I think a
# histogram will be a good way to visualize this, but I could potentially create a story in
# Tableau which might walk the viewer through the information.

# %%
q4 = city_state_data
q4 = q4[["Date","Year","Month","RegionName","ZHVI_1bedroom","ZHVI_2bedroom","ZHVI_3bedroom","ZHVI_4bedroom","ZHVI_5BedroomOrMore","ZHVIPerSqft_AllHomes","ZHVI_BottomTier","ZHVI_MiddleTier","ZHVI_SingleFamilyResidence","ZHVI_TopTier","State","County","City"]]

# %%
q4 = q4.dropna()
q4.head()
# Out:
#          Date  Year  Month            RegionName  ZHVI_1bedroom  \
# 10 1996-04-30  1996      4  abingtonmontgomerypa        47500.0
# 18 1996-04-30  1996      4      actonmiddlesexma        52400.0
# 21 1996-04-30  1996      4         acworthcobbga        62200.0
# 44 1996-04-30  1996      4       agawamhampdenma        35800.0
# 55 1996-04-30  1996      4         akronsummitoh        41600.0
#
#     ZHVI_2bedroom  ZHVI_3bedroom  ZHVI_4bedroom  ZHVI_5BedroomOrMore  \
# 10       102200.0       122000.0       157600.0             219000.0
# 18       122200.0       212500.0       288100.0             325500.0
# 21        75500.0       100800.0       155900.0             201300.0
# 44        82100.0       107400.0       114100.0             127300.0
# 55        49100.0        59500.0        70000.0              74900.0
#
#     ZHVIPerSqft_AllHomes  ZHVI_BottomTier  ZHVI_MiddleTier  \
# 10                  78.0         102000.0         128700.0
# 18                 118.0         128200.0         230500.0
# 21                  60.0          83900.0         112900.0
# 44                  71.0          68600.0         101500.0
# 55                  49.0          42800.0          57100.0
#
#     ZHVI_SingleFamilyResidence  ZHVI_TopTier State      County      City
# 10                    130900.0      189400.0    PA  Montgomery  Abington
# 18                    253900.0      330100.0    MA   Middlesex     Acton
# 21                    114800.0      174000.0    GA        Cobb   Acworth
# 44                    106800.0      124700.0    MA     Hampden    Agawam
# 55                     56300.0       88000.0    OH      Summit     Akron

# %%
ann_arbor = q4.loc[q4["RegionName"]=="ann_arborwashtenawmi"]

# %%
ann_arbor.head()
# Out:
#             Date  Year  Month            RegionName  ZHVI_1bedroom  \
# 209   1996-04-30  1996      4  ann_arborwashtenawmi        90300.0
# 11639 1996-05-31  1996      5  ann_arborwashtenawmi        87500.0
# 23211 1996-06-30  1996      6  ann_arborwashtenawmi        84100.0
# 34842 1996-07-31  1996      7  ann_arborwashtenawmi        81100.0
# 46479 1996-08-31  1996      8  ann_arborwashtenawmi        80700.0
#
#        ZHVI_2bedroom  ZHVI_3bedroom  ZHVI_4bedroom  ZHVI_5BedroomOrMore  \
# 209         107300.0       129000.0       188500.0             220200.0
# 11639       107500.0       130400.0       188600.0             219300.0
# 23211       107700.0       131500.0       188800.0             220700.0
# 34842       108600.0       132200.0       189100.0             222600.0
# 46479       109200.0       133200.0       189500.0             224800.0
#
#        ZHVIPerSqft_AllHomes  ZHVI_BottomTier  ZHVI_MiddleTier  \
# 209                    95.0         106900.0         152000.0
# 11639                  96.0         107900.0         153100.0
# 23211                  97.0         108300.0         154200.0
# 34842                  97.0         108900.0         154900.0
# 46479                  97.0         109300.0         155300.0
#
#        ZHVI_SingleFamilyResidence  ZHVI_TopTier State     County       City
# 209                      157300.0      248200.0    MI  Washtenaw  Ann Arbor
# 11639                    158500.0      249500.0    MI  Washtenaw  Ann Arbor
# 23211                    159700.0      250900.0    MI  Washtenaw  Ann Arbor
# 34842                    160300.0      251100.0    MI  Washtenaw  Ann Arbor
# 46479                    160500.0      251500.0    MI  Washtenaw  Ann Arbor

# %%
ann_arbor2017 = ann_arbor.loc[ann_arbor["Year"]==2017]

# %%
ann_arbor2017["ZHVI_1bedroom"].median()
# Out:
# 171350.0

# %%
ann_arbor2017["ZHVI_2bedroom"].median()
# Out:
# 233000.0

# %%
ann_arbor2017["ZHVI_3bedroom"].median()
# Out:
# 303150.0

# %%
ann_arbor2017["ZHVI_4bedroom"].median()
# Out:
# 408050.0

# %%
ann_arbor2017["ZHVI_5BedroomOrMore"].median()
# Out:
# 568850.0

# %%
ann_arbor2012 = ann_arbor.loc[ann_arbor["Year"]==2012]

# %%
ann_arbor2012["ZHVI_1bedroom"].median()
# Out:
# 142800.0

# %%
ann_arbor2012["ZHVI_2bedroom"].median()
# Out:
# 157750.0

# %%
ann_arbor2012["ZHVI_3bedroom"].median()
# Out:
# 204450.0

# %%
ann_arbor2012["ZHVI_4bedroom"].median()
# Out:
# 279500.0

# %%
ann_arbor2012["ZHVI_5BedroomOrMore"].median()
# Out:
# 365800.0

# %%
ann_arbor2007 = ann_arbor.loc[ann_arbor["Year"]==2007]

# %%
ann_arbor2007["ZHVI_1bedroom"].median()
# Out:
# 160400.0

# %%
ann_arbor2007["ZHVI_2bedroom"].median()
# Out:
# 173050.0

# %%
ann_arbor2007["ZHVI_3bedroom"].median()
# Out:
# 220000.0

# %%
ann_arbor2007["ZHVI_4bedroom"].median()
# Out:
# 295500.0

# %%
ann_arbor2007["ZHVI_5BedroomOrMore"].median()
# Out:
# 403150.0

# %%
ann_arbor2002 = ann_arbor.loc[ann_arbor["Year"]==2002]

# %%
ann_arbor2002["ZHVI_1bedroom"].median()
# Out:
# 131750.0

# %%
ann_arbor2002["ZHVI_2bedroom"].median()
# Out:
# 173650.0

# %%
ann_arbor2002["ZHVI_3bedroom"].median()
# Out:
# 219950.0

# %%
ann_arbor2002["ZHVI_4bedroom"].median()
# Out:
# 299700.0

# %%
ann_arbor2002["ZHVI_5BedroomOrMore"].median()
# Out:
# 376850.0

# %% [markdown]
# **QUESTION 5: (Extra) Determine which cities are likely to experience an increase in housing prices
# in the coming years.**

# %% [markdown]
# (Extra) Use machine learning regression to determine which city is likely to have the
# largest price increase over the coming 1, 5 and 10 years. (Where does it make sense
# to invest?) Plot the results in a scatterplot with seaborn?

# %%
q5 = city_state_data

# %%
q5 = q5.loc[q5["State"]=='MI']
q5 = q5[["Date","Year","Month","RegionName","ZHVI_1bedroom","ZHVI_2bedroom","ZHVI_3bedroom","ZHVI_4bedroom","ZHVI_5BedroomOrMore","ZHVIPerSqft_AllHomes","ZHVI_BottomTier","ZHVI_MiddleTier","ZHVI_SingleFamilyResidence","ZHVI_TopTier","State","County","City"]]
q5 = q5.dropna()

# %%
q5.head()
# Out:
#            Date  Year  Month                 RegionName  ZHVI_1bedroom  \
# 209  1996-04-30  1996      4       ann_arborwashtenawmi        90300.0
# 844  1996-04-30  1996      4  bloomfield_hillsoaklandmi        61500.0
# 3183 1996-04-30  1996      4          ferndaleoaklandmi        60700.0
# 3787 1996-04-30  1996      4         grand_rapidskentmi        71700.0
# 4188 1996-04-30  1996      4        hazel_parkoaklandmi        42000.0
#
#       ZHVI_2bedroom  ZHVI_3bedroom  ZHVI_4bedroom  ZHVI_5BedroomOrMore  \
# 209        107300.0       129000.0       188500.0             220200.0
# 844        117800.0       215800.0       315100.0             528700.0
# 3183        63000.0        75800.0        95700.0              95100.0
# 3787        63100.0        71500.0        78300.0              86200.0
# 4188        43800.0        54600.0        64100.0              71100.0
#
#       ZHVIPerSqft_AllHomes  ZHVI_BottomTier  ZHVI_MiddleTier  \
# 209                   95.0         106900.0         152000.0
# 844                  108.0         170000.0         270000.0
# 3183                  71.0          58600.0          71000.0
# 3787                  50.0          45900.0          65800.0
# 4188                  53.0          42300.0          51500.0
#
#       ZHVI_SingleFamilyResidence  ZHVI_TopTier State     County  \
# 209                     157300.0      248200.0    MI  Washtenaw
# 844                     299500.0      541900.0    MI    Oakland
# 3183                     71000.0      101200.0    MI    Oakland
# 3787                     64300.0      105600.0    MI       Kent
# 4188                     51500.0       64500.0    MI    Oakland
#
#                   City
# 209          Ann Arbor
# 844   Bloomfield Hills
# 3183          Ferndale
# 3787      Grand Rapids
# 4188        Hazel Park

# %%
q5_2017 = q5.loc[q5["Year"]==2017]
q5_2017 = q5_2017.loc[q5_2017["Month"]==5]
#q5_2017.head()
q5_2015 = q5.loc[q5["Year"]==2015]
q5_2015 = q5_2015.loc[q5_2015["Month"]==5]

# %%
#q5_2017.head()

# %%
q5_a = pd.merge(q5_2017,q5_2015, on='RegionName')

# %%
q5_a = q5_a[["RegionName","Year_x","ZHVIPerSqft_AllHomes_x","Year_y","ZHVIPerSqft_AllHomes_y"]]

# %%
q5_a['Dif'] = q5_a["ZHVIPerSqft_AllHomes_x"] - q5_a["ZHVIPerSqft_AllHomes_y"]

# %%
q5_a
# Out:
#                      RegionName  Year_x  ZHVIPerSqft_AllHomes_x  Year_y  \
# 0          ann_arborwashtenawmi    2017                   208.0    2015
# 1     bloomfield_hillsoaklandmi    2017                   170.0    2015
# 2          brightonlivingstonmi    2017                   143.0    2015
# 3                detroitwaynemi    2017                    40.0    2015
# 4     farmington_hillsoaklandmi    2017                   124.0    2015
# 5             ferndaleoaklandmi    2017                   136.0    2015
# 6                flintgeneseemi    2017                    40.0    2015
# 7            grand_rapidskentmi    2017                   101.0    2015
# 8           hazel_parkoaklandmi    2017                    67.0    2015
# 9               hollandottawami    2017                   126.0    2015
# 10               livoniawaynemi    2017                   134.0    2015
# 11    milford_townshipoaklandmi    2017                   148.0    2015
# 12  muskegon_townshipmuskegonmi    2017                    60.0    2015
# 13      norton_shoresmuskegonmi    2017                    97.0    2015
# 14     rochester_hillsoaklandmi    2017                   137.0    2015
# 15             saginawsaginawmi    2017                    47.0    2015
# 16   saint_clair_shoresmacombmi    2017                   116.0    2015
# 17          south_lyonoaklandmi    2017                   145.0    2015
# 18                troyoaklandmi    2017                   147.0    2015
# 19           waterfordoaklandmi    2017                   113.0    2015
# 20     west_bloomfieldoaklandmi    2017                   126.0    2015
#
#     ZHVIPerSqft_AllHomes_y   Dif
# 0                    184.0  24.0
# 1                    161.0   9.0
# 2                    129.0  14.0
# 3                     34.0   6.0
# 4                    113.0  11.0
# 5                    108.0  28.0
# 6                     32.0   8.0
# 7                     79.0  22.0
# 8                     55.0  12.0
# 9                    107.0  19.0
# 10                   117.0  17.0
# 11                   134.0  14.0
# 12                    51.0   9.0
# 13                    82.0  15.0
# 14                   126.0  11.0
# 15                    43.0   4.0
# 16                    97.0  19.0
# 17                   131.0  14.0
# 18                   133.0  14.0
# 19                    98.0  15.0
# 20                   116.0  10.0

# %%
q5_a['Label'] = np.where(q5_a['Dif']>=10 ,'yes','no')
q5_a
# Out:
#                      RegionName  Year_x  ZHVIPerSqft_AllHomes_x  Year_y  \
# 0          ann_arborwashtenawmi    2017                   208.0    2015
# 1     bloomfield_hillsoaklandmi    2017                   170.0    2015
# 2          brightonlivingstonmi    2017                   143.0    2015
# 3                detroitwaynemi    2017                    40.0    2015
# 4     farmington_hillsoaklandmi    2017                   124.0    2015
# 5             ferndaleoaklandmi    2017                   136.0    2015
# 6                flintgeneseemi    2017                    40.0    2015
# 7            grand_rapidskentmi    2017                   101.0    2015
# 8           hazel_parkoaklandmi    2017                    67.0    2015
# 9               hollandottawami    2017                   126.0    2015
# 10               livoniawaynemi    2017                   134.0    2015
# 11    milford_townshipoaklandmi    2017                   148.0    2015
# 12  muskegon_townshipmuskegonmi    2017                    60.0    2015
# 13      norton_shoresmuskegonmi    2017                    97.0    2015
# 14     rochester_hillsoaklandmi    2017                   137.0    2015
# 15             saginawsaginawmi    2017                    47.0    2015
# 16   saint_clair_shoresmacombmi    2017                   116.0    2015
# 17          south_lyonoaklandmi    2017                   145.0    2015
# 18                troyoaklandmi    2017                   147.0    2015
# 19           waterfordoaklandmi    2017                   113.0    2015
# 20     west_bloomfieldoaklandmi    2017                   126.0    2015
#
#     ZHVIPerSqft_AllHomes_y   Dif Label
# 0                    184.0  24.0   yes
# 1                    161.0   9.0    no
# 2                    129.0  14.0   yes
# 3                     34.0   6.0    no
# 4                    113.0  11.0   yes
# 5                    108.0  28.0   yes
# 6                     32.0   8.0    no
# 7                     79.0  22.0   yes
# 8                     55.0  12.0   yes
# 9                    107.0  19.0   yes
# 10                   117.0  17.0   yes
# 11                   134.0  14.0   yes
# 12                    51.0   9.0    no
# 13                    82.0  15.0   yes
# 14                   126.0  11.0   yes
# 15                    43.0   4.0    no
# 16                    97.0  19.0   yes
# 17                   131.0  14.0   yes
# 18                   133.0  14.0   yes
# 19                    98.0  15.0   yes
# 20                   116.0  10.0   yes

# %%
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
import sklearn.ensemble as skens
import sklearn.metrics as skmetric
import sklearn.naive_bayes as sknb
import sklearn.tree as sktree
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style='white', color_codes=True, font_scale=1.3)
import sklearn.externals.six as sksix
import IPython.display as ipd
from sklearn.model_selection import cross_val_score
from sklearn import metrics
import os
from sklearn.metrics import accuracy_score

# %%
df_q5_train,df_q5_test = train_test_split(q5_a, test_size=0.3)

# %%
gnb_model = sknb.GaussianNB()
# given sepal length, predict if setosa
gnb_model.fit(df_q5_train[['ZHVIPerSqft_AllHomes_y']],df_q5_train['Label'])
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb_model.predict(df_q5_test[['ZHVIPerSqft_AllHomes_y']])
df_q5_test['predicted_nb'] = y_pred
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_q5_test
# Out:
#              RegionName  Year_x  ZHVIPerSqft_AllHomes_x  Year_y  \
# 15     saginawsaginawmi    2017                    47.0    2015
# 17  south_lyonoaklandmi    2017                   145.0    2015
# 9       hollandottawami    2017                   126.0    2015
# 7    grand_rapidskentmi    2017                   101.0    2015
# 5     ferndaleoaklandmi    2017                   136.0    2015
# 18        troyoaklandmi    2017                   147.0    2015
# 3        detroitwaynemi    2017                    40.0    2015
#
#     ZHVIPerSqft_AllHomes_y   Dif Label predicted_nb
# 15                    43.0   4.0    no           no
# 17                   131.0  14.0   yes          yes
# 9                    107.0  19.0   yes          yes
# 7                     79.0  22.0   yes          yes
# 5                    108.0  28.0   yes          yes
# 18                   133.0  14.0   yes          yes
# 3                     34.0   6.0    no           no

# %%
accuracy_score(df_q5_test["Label"], df_q5_test["predicted_nb"])
# Out:
# 1.0

# %%
y_pred = gnb_model.predict(df_q5_test[['ZHVIPerSqft_AllHomes_x']])
df_q5_test['predicted_nb2'] = y_pred
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_q5_test
# Out:
#              RegionName  Year_x  ZHVIPerSqft_AllHomes_x  Year_y  \
# 15     saginawsaginawmi    2017                    47.0    2015
# 17  south_lyonoaklandmi    2017                   145.0    2015
# 9       hollandottawami    2017                   126.0    2015
# 7    grand_rapidskentmi    2017                   101.0    2015
# 5     ferndaleoaklandmi    2017                   136.0    2015
# 18        troyoaklandmi    2017                   147.0    2015
# 3        detroitwaynemi    2017                    40.0    2015
#
#     ZHVIPerSqft_AllHomes_y   Dif Label predicted_nb predicted_nb2
# 15                    43.0   4.0    no           no            no
# 17                   131.0  14.0   yes          yes           yes
# 9                    107.0  19.0   yes          yes           yes
# 7                     79.0  22.0   yes          yes           yes
# 5                    108.0  28.0   yes          yes           yes
# 18                   133.0  14.0   yes          yes           yes
# 3                     34.0   6.0    no           no            no

# %% [markdown]
# Whole Country

# %%
q5_b = comparison_b_graph

# %%
conditions = [
    (q5_b['Dif'] >= 100 ) & (q5_b['Dif'] <= 500),
    (q5_b['Dif'] < 100 ) ,
    (q5_b['Dif'] > 500 )]
choices = ['yes', 'no', 'no']
q5_b['Label'] = np.select(conditions, choices, default='null')

# %%
df_q5B_train,df_q5B_test = train_test_split(q5_b, test_size=0.3)

# %%
gnb_model = sknb.GaussianNB()
# given sepal length, predict if setosa
gnb_model.fit(df_q5B_train[['ZHVIPerSqft_AllHomes_y']],df_q5B_train['Label'])
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
y_pred = gnb_model.predict(df_q5B_test[['ZHVIPerSqft_AllHomes_y']])
df_q5B_test['predicted_nb'] = y_pred
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_q5B_test
# Out:
#           Date_x                       RegionName  ZHVIPerSqft_AllHomes_x  \
# 7227  2017-05-31                   newportperrypa                    53.0
# 460   2017-05-31                 bainbridgerossoh                    71.0
# 196   2017-05-31                   andoveranokamn                   200.0
# 5439  2017-05-31                   lakelandpolkfl                   100.0
# 7940  2017-05-31         pass_christianharrisonms                    81.0
# 221   2017-05-31                   annawanhenryil                    83.0
# 11513 2017-05-31         west_harwichbarnstablema                   278.0
# 1037  2017-05-31               braintreenorfolkma                   273.0
# 4178  2017-05-31    grover_beachsan_luis_obispoca                   340.0
# 3694  2017-05-31                gadsdenrichlandsc                    65.0
# 7861  2017-05-31               palo_cedroshastaca                   176.0
# 10464 2017-05-31  town_of_canajohariemontgomeryny                    54.0
# 2663  2017-05-31                dovertuscarawasoh                    94.0
# 10657 2017-05-31        town_of_newportsullivannh                    79.0
# 7191  2017-05-31                    newberndyertn                    55.0
# 8355  2017-05-31             port_orchardkitsapwa                   208.0
# 640   2017-05-31                 belcampharfordmd                   132.0
# 11002 2017-05-31  upper_uwchlan_townshipchesterpa                   162.0
# 9977  2017-05-31               stillwatersussexnj                   146.0
# 2511  2017-05-31       del_monte_forestmontereyca                   757.0
# 4578  2017-05-31                 highlandhowardmd                   239.0
# 11924 2017-05-31               woodbinecape_maynj                   144.0
# 4807  2017-05-31               huntingtoncabellwv                    60.0
# 9639  2017-05-31                  solwayhubbardmn                   102.0
# 152   2017-05-31                   altusjacksonok                    49.0
# 8634  2017-05-31                     renoparkertx                   105.0
# 3684  2017-05-31                fullertonorangeca                   387.0
# 1119  2017-05-31                brimfieldpeoriail                   106.0
# 3874  2017-05-31                glen_ridgeessexnj                   301.0
# 4031  2017-05-31               granitesalt_lakeut                   245.0
# ...          ...                              ...                     ...
# 6017  2017-05-31                      lyonslinnor                   174.0
# 11860 2017-05-31          windsor_lockshartfordct                   130.0
# 4979  2017-05-31               janesvillelassenca                   135.0
# 11868 2017-05-31                  windsorsonomaca                   342.0
# 10922 2017-05-31                   unicoiunicoitn                    83.0
# 3666  2017-05-31             friendsvilleblounttn                   104.0
# 10261 2017-05-31             templetonworcesterma                   137.0
# 10386 2017-05-31                  toolhendersontx                    98.0
# 7204  2017-05-31               newcastlelincolnme                   123.0
# 3945  2017-05-31            goletasanta_barbaraca                   511.0
# 5726  2017-05-31               lindencumberlandnc                    92.0
# 4585  2017-05-31                 highlandsmaconnc                   226.0
# 3820  2017-05-31              geyservillesonomaca                   511.0
# 3444  2017-05-31             flowery_branchhallga                   113.0
# 6964  2017-05-31        munsons_cornerscortlandny                    98.0
# 8189  2017-05-31      pistakee_highlandsmchenryil                   127.0
# 9267  2017-05-31         saugerties_southulsterny                   147.0
# 7694  2017-05-31                  orfordgraftonnh                   117.0
# 8740  2017-05-31                rio_vistasolanoca                   215.0
# 7562  2017-05-31            ocean_cityworcestermd                   234.0
# 4440  2017-05-31                 haywardalamedaca                   427.0
# 3093  2017-05-31             elmwood_parkbergennj                   210.0
# 10767 2017-05-31         town_of_waltondelawareny                    59.0
# 3548  2017-05-31            fountain_hilllehighpa                    84.0
# 270   2017-05-31                   ardmoregilestn                    76.0
# 10918 2017-05-31                   umatillalakefl                   100.0
# 8688  2017-05-31                richmondmchenryil                   111.0
# 1690  2017-05-31           chatsworthlivingstonil                    45.0
# 7888  2017-05-31                   paradisewisetx                   117.0
# 11942 2017-05-31           woodcliff_lakebergennj                   287.0
#
#        Year_x  Month_x                  City_x         County_x State_x  \
# 7227     2017        5                 Newport            Perry      PA
# 460      2017        5              Bainbridge             Ross      OH
# 196      2017        5                 Andover            Anoka      MN
# 5439     2017        5                Lakeland             Polk      FL
# 7940     2017        5          Pass Christian         Harrison      MS
# 221      2017        5                 Annawan            Henry      IL
# 11513    2017        5            West Harwich       Barnstable      MA
# 1037     2017        5               Braintree          Norfolk      MA
# 4178     2017        5            Grover Beach  San Luis Obispo      CA
# 3694     2017        5                 Gadsden         Richland      SC
# 7861     2017        5              Palo Cedro           Shasta      CA
# 10464    2017        5     Town of Canajoharie       Montgomery      NY
# 2663     2017        5                   Dover       Tuscarawas      OH
# 10657    2017        5         Town of Newport         Sullivan      NH
# 7191     2017        5                 Newbern             Dyer      TN
# 8355     2017        5            Port Orchard           Kitsap      WA
# 640      2017        5                 Belcamp          Harford      MD
# 11002    2017        5  Upper Uwchlan Township          Chester      PA
# 9977     2017        5              Stillwater           Sussex      NJ
# 2511     2017        5        Del Monte Forest         Monterey      CA
# 4578     2017        5                Highland           Howard      MD
# 11924    2017        5                Woodbine         Cape May      NJ
# 4807     2017        5              Huntington           Cabell      WV
# 9639     2017        5                  Solway          Hubbard      MN
# 152      2017        5                   Altus          Jackson      OK
# 8634     2017        5                    Reno           Parker      TX
# 3684     2017        5               Fullerton           Orange      CA
# 1119     2017        5               Brimfield           Peoria      IL
# 3874     2017        5              Glen Ridge            Essex      NJ
# 4031     2017        5                 Granite        Salt Lake      UT
# ...       ...      ...                     ...              ...     ...
# 6017     2017        5                   Lyons             Linn      OR
# 11860    2017        5           Windsor Locks         Hartford      CT
# 4979     2017        5              Janesville           Lassen      CA
# 11868    2017        5                 Windsor           Sonoma      CA
# 10922    2017        5                  Unicoi           Unicoi      TN
# 3666     2017        5            Friendsville           Blount      TN
# 10261    2017        5               Templeton        Worcester      MA
# 10386    2017        5                    Tool        Henderson      TX
# 7204     2017        5               Newcastle          Lincoln      ME
# 3945     2017        5                  Goleta    Santa Barbara      CA
# 5726     2017        5                  Linden       Cumberland      NC
# 4585     2017        5               Highlands            Macon      NC
# 3820     2017        5             Geyserville           Sonoma      CA
# 3444     2017        5          Flowery Branch             Hall      GA
# 6964     2017        5         Munsons Corners         Cortland      NY
# 8189     2017        5      Pistakee Highlands          McHenry      IL
# 9267     2017        5        Saugerties South           Ulster      NY
# 7694     2017        5                  Orford          Grafton      NH
# 8740     2017        5               Rio Vista           Solano      CA
# 7562     2017        5              Ocean City        Worcester      MD
# 4440     2017        5                 Hayward          Alameda      CA
# 3093     2017        5            Elmwood Park           Bergen      NJ
# 10767    2017        5          Town of Walton         Delaware      NY
# 3548     2017        5           Fountain Hill           Lehigh      PA
# 270      2017        5                 Ardmore            Giles      TN
# 10918    2017        5                Umatilla             Lake      FL
# 8688     2017        5                Richmond          McHenry      IL
# 1690     2017        5              Chatsworth       Livingston      IL
# 7888     2017        5                Paradise             Wise      TX
# 11942    2017        5          Woodcliff Lake           Bergen      NJ
#
#           Date_y  ZHVIPerSqft_AllHomes_y  Year_y  Month_y  \
# 7227  2012-05-31                    51.0    2012        5
# 460   2012-05-31                    57.0    2012        5
# 196   2012-05-31                   130.0    2012        5
# 5439  2012-05-31                    62.0    2012        5
# 7940  2012-05-31                    85.0    2012        5
# 221   2012-05-31                    78.0    2012        5
# 11513 2012-05-31                   245.0    2012        5
# 1037  2012-05-31                   203.0    2012        5
# 4178  2012-05-31                   219.0    2012        5
# 3694  2012-05-31                    56.0    2012        5
# 7861  2012-05-31                   122.0    2012        5
# 10464 2012-05-31                    52.0    2012        5
# 2663  2012-05-31                    77.0    2012        5
# 10657 2012-05-31                    81.0    2012        5
# 7191  2012-05-31                    44.0    2012        5
# 8355  2012-05-31                   136.0    2012        5
# 640   2012-05-31                   129.0    2012        5
# 11002 2012-05-31                   138.0    2012        5
# 9977  2012-05-31                   142.0    2012        5
# 2511  2012-05-31                   524.0    2012        5
# 4578  2012-05-31                   216.0    2012        5
# 11924 2012-05-31                   135.0    2012        5
# 4807  2012-05-31                    61.0    2012        5
# 9639  2012-05-31                    77.0    2012        5
# 152   2012-05-31                    42.0    2012        5
# 8634  2012-05-31                    75.0    2012        5
# 3684  2012-05-31                   257.0    2012        5
# 1119  2012-05-31                   106.0    2012        5
# 3874  2012-05-31                   238.0    2012        5
# 4031  2012-05-31                   184.0    2012        5
# ...          ...                     ...     ...      ...
# 6017  2012-05-31                   123.0    2012        5
# 11860 2012-05-31                   127.0    2012        5
# 4979  2012-05-31                   100.0    2012        5
# 11868 2012-05-31                   192.0    2012        5
# 10922 2012-05-31                    70.0    2012        5
# 3666  2012-05-31                    86.0    2012        5
# 10261 2012-05-31                   112.0    2012        5
# 10386 2012-05-31                    76.0    2012        5
# 7204  2012-05-31                   117.0    2012        5
# 3945  2012-05-31                   343.0    2012        5
# 5726  2012-05-31                    88.0    2012        5
# 4585  2012-05-31                   181.0    2012        5
# 3820  2012-05-31                   320.0    2012        5
# 3444  2012-05-31                    79.0    2012        5
# 6964  2012-05-31                    90.0    2012        5
# 8189  2012-05-31                   100.0    2012        5
# 9267  2012-05-31                   136.0    2012        5
# 7694  2012-05-31                   105.0    2012        5
# 8740  2012-05-31                   118.0    2012        5
# 7562  2012-05-31                   229.0    2012        5
# 4440  2012-05-31                   208.0    2012        5
# 3093  2012-05-31                   174.0    2012        5
# 10767 2012-05-31                    63.0    2012        5
# 3548  2012-05-31                    77.0    2012        5
# 270   2012-05-31                    58.0    2012        5
# 10918 2012-05-31                    64.0    2012        5
# 8688  2012-05-31                    92.0    2012        5
# 1690  2012-05-31                    41.0    2012        5
# 7888  2012-05-31                    90.0    2012        5
# 11942 2012-05-31                   250.0    2012        5
#
#                        City_y         County_y State_y    Dif Label  \
# 7227                  Newport            Perry      PA    2.0    no
# 460                Bainbridge             Ross      OH   14.0    no
# 196                   Andover            Anoka      MN   70.0    no
# 5439                 Lakeland             Polk      FL   38.0    no
# 7940           Pass Christian         Harrison      MS   -4.0    no
# 221                   Annawan            Henry      IL    5.0    no
# 11513            West Harwich       Barnstable      MA   33.0    no
# 1037                Braintree          Norfolk      MA   70.0    no
# 4178             Grover Beach  San Luis Obispo      CA  121.0   yes
# 3694                  Gadsden         Richland      SC    9.0    no
# 7861               Palo Cedro           Shasta      CA   54.0    no
# 10464     Town of Canajoharie       Montgomery      NY    2.0    no
# 2663                    Dover       Tuscarawas      OH   17.0    no
# 10657         Town of Newport         Sullivan      NH   -2.0    no
# 7191                  Newbern             Dyer      TN   11.0    no
# 8355             Port Orchard           Kitsap      WA   72.0    no
# 640                   Belcamp          Harford      MD    3.0    no
# 11002  Upper Uwchlan Township          Chester      PA   24.0    no
# 9977               Stillwater           Sussex      NJ    4.0    no
# 2511         Del Monte Forest         Monterey      CA  233.0   yes
# 4578                 Highland           Howard      MD   23.0    no
# 11924                Woodbine         Cape May      NJ    9.0    no
# 4807               Huntington           Cabell      WV   -1.0    no
# 9639                   Solway          Hubbard      MN   25.0    no
# 152                     Altus          Jackson      OK    7.0    no
# 8634                     Reno           Parker      TX   30.0    no
# 3684                Fullerton           Orange      CA  130.0   yes
# 1119                Brimfield           Peoria      IL    0.0    no
# 3874               Glen Ridge            Essex      NJ   63.0    no
# 4031                  Granite        Salt Lake      UT   61.0    no
# ...                       ...              ...     ...    ...   ...
# 6017                    Lyons             Linn      OR   51.0    no
# 11860           Windsor Locks         Hartford      CT    3.0    no
# 4979               Janesville           Lassen      CA   35.0    no
# 11868                 Windsor           Sonoma      CA  150.0   yes
# 10922                  Unicoi           Unicoi      TN   13.0    no
# 3666             Friendsville           Blount      TN   18.0    no
# 10261               Templeton        Worcester      MA   25.0    no
# 10386                    Tool        Henderson      TX   22.0    no
# 7204                Newcastle          Lincoln      ME    6.0    no
# 3945                   Goleta    Santa Barbara      CA  168.0   yes
# 5726                   Linden       Cumberland      NC    4.0    no
# 4585                Highlands            Macon      NC   45.0    no
# 3820              Geyserville           Sonoma      CA  191.0   yes
# 3444           Flowery Branch             Hall      GA   34.0    no
# 6964          Munsons Corners         Cortland      NY    8.0    no
# 8189       Pistakee Highlands          McHenry      IL   27.0    no
# 9267         Saugerties South           Ulster      NY   11.0    no
# 7694                   Orford          Grafton      NH   12.0    no
# 8740                Rio Vista           Solano      CA   97.0    no
# 7562               Ocean City        Worcester      MD    5.0    no
# 4440                  Hayward          Alameda      CA  219.0   yes
# 3093             Elmwood Park           Bergen      NJ   36.0    no
# 10767          Town of Walton         Delaware      NY   -4.0    no
# 3548            Fountain Hill           Lehigh      PA    7.0    no
# 270                   Ardmore            Giles      TN   18.0    no
# 10918                Umatilla             Lake      FL   36.0    no
# 8688                 Richmond          McHenry      IL   19.0    no
# 1690               Chatsworth       Livingston      IL    4.0    no
# 7888                 Paradise             Wise      TX   27.0    no
# 11942          Woodcliff Lake           Bergen      NJ   37.0    no
#
#       predicted_nb
# 7227            no
# 460             no
# 196             no
# 5439            no
# 7940            no
# 221             no
# 11513           no
# 1037            no
# 4178            no
# 3694            no
# 7861            no
# 10464           no
# 2663            no
# 10657           no
# 7191            no
# 8355            no
# 640             no
# 11002           no
# 9977            no
# 2511           yes
# 4578            no
# 11924           no
# 4807            no
# 9639            no
# 152             no
# 8634            no
# 3684           yes
# 1119            no
# 3874            no
# 4031            no
# ...            ...
# 6017            no
# 11860           no
# 4979            no
# 11868           no
# 10922           no
# 3666            no
# 10261           no
# 10386           no
# 7204            no
# 3945           yes
# 5726            no
# 4585            no
# 3820           yes
# 3444            no
# 6964            no
# 8189            no
# 9267            no
# 7694            no
# 8740            no
# 7562            no
# 4440            no
# 3093            no
# 10767           no
# 3548            no
# 270             no
# 10918           no
# 8688            no
# 1690            no
# 7888            no
# 11942           no
#
# [3630 rows x 18 columns]

# %%
accuracy_score(df_q5B_test["Label"], df_q5B_test["predicted_nb"])
# Out:
# 0.953168044077135

# %%
# utility class to compare the predictions versus ground truth
def comparePlot(input_frame,real_column,predicted_column):
    df_a = input_frame.copy()
    df_b = input_frame.copy()
    df_a['label_source'] = 'ZHVIPerSqft_AllHomes_y'
    df_b['label_source'] = 'ZHVIPerSqft_AllHomes_x'
    df_a['label'] = df_a[real_column]
    df_b['label'] = df_b[predicted_column].apply(lambda x: 'Predict %s'%x)
    df_c = pd.concat((df_a, df_b), axis=0, ignore_index=True)
    sns.lmplot(x='ZHVIPerSqft_AllHomes_y', y='ZHVIPerSqft_AllHomes_x', col='label_source',
               hue='label', data=df_c, fit_reg=False, size=4);

# %%
comparePlot(df_q5B_test,"ZHVIPerSqft_AllHomes_y","predicted_nb")
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
y_pred = gnb_model.predict(df_q5B_test[['ZHVIPerSqft_AllHomes_x']])
df_q5B_test['predicted_nb2'] = y_pred
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_q5B_test.sample(100)
# Out:
#           Date_x                        RegionName  ZHVIPerSqft_AllHomes_x  \
# 5240  2017-05-31               kingsvilleklebergtx                    63.0
# 6370  2017-05-31                  mebanealamancenc                   104.0
# 5704  2017-05-31             limestonewashingtontn                    82.0
# 4082  2017-05-31             green_treealleghenypa                   120.0
# 10865 2017-05-31             tuckahoewestchesterny                   329.0
# 7971  2017-05-31                      paysonutahut                   160.0
# 6904  2017-05-31         mount_vernonwestchesterny                   231.0
# 10550 2017-05-31        town_of_grotonnew_londonct                   147.0
# 3037  2017-05-31           elizabethvilledauphinpa                    75.0
# 5026  2017-05-31                    jeromejeromeid                    93.0
# 1381  2017-05-31                    cameronmilamtx                    56.0
# 198   2017-05-31                   andoverbutlerks                    77.0
# 6733  2017-05-31               montgomerychathamga                   123.0
# 11922 2017-05-31           wood_villagemultnomahor                   182.0
# 8328  2017-05-31          poplarvillepearl_riverms                    70.0
# 9164  2017-05-31              san_clementeorangeca                   462.0
# 6758  2017-05-31                 monumentel_pasoco                   146.0
# 7417  2017-05-31             north_uticala_salleil                    99.0
# 1048  2017-05-31                       branterieny                   105.0
# 4529  2017-05-31          hesperiasan_bernardinoca                   142.0
# 3739  2017-05-31             garden_prairiebooneil                    98.0
# 6112  2017-05-31              manchesterhartfordct                   123.0
# 9100  2017-05-31       saint_paul_parkwashingtonmn                   125.0
# 6244  2017-05-31                  marshfieldwoodwi                    78.0
# 1222  2017-05-31                 buckeyemaricopaaz                   107.0
# 5701  2017-05-31              limerickmontgomerypa                   143.0
# 1052  2017-05-31               bratenahlcuyahogaoh                   109.0
# 3221  2017-05-31               ewa_beachhonoluluhi                   425.0
# 7932  2017-05-31             parsonsburgwicomicomd                   104.0
# 9607  2017-05-31                smithvilledekalbtn                    74.0
# ...          ...                               ...                     ...
# 4444  2017-05-31           hazel_dell_southclarkwa                   190.0
# 8722  2017-05-31                     rigalenaweemi                    74.0
# 5821  2017-05-31                      lodibergennj                   223.0
# 6524  2017-05-31                  midlandmidlandtx                   107.0
# 1148  2017-05-31                     bronsonlevyfl                    75.0
# 11418 2017-05-31    weeki_wachee_gardenshernandofl                   151.0
# 7537  2017-05-31                   oaklandorangefl                   125.0
# 7143  2017-05-31        new_marlboroughberkshirema                   185.0
# 4914  2017-05-31               irondalejeffersonal                    88.0
# 3694  2017-05-31                 gadsdenrichlandsc                    65.0
# 11506 2017-05-31           west_friendshiphowardmd                   227.0
# 3748  2017-05-31                  gardnerjohnsonks                   133.0
# 10562 2017-05-31        town_of_herkimerherkimerny                    51.0
# 4354  2017-05-31                 harrisoncalumetwi                   108.0
# 11090 2017-05-31           vernon_townshipsussexnj                   131.0
# 9463  2017-05-31                    shelbyshelbyal                   138.0
# 3254  2017-05-31  fairfield_townshipwestmorelandpa                   110.0
# 10058 2017-05-31               sugar_citymadisonid                    83.0
# 2194  2017-05-31                 coronariversideca                   235.0
# 6613  2017-05-31         mineral_pointwashingtonmo                    81.0
# 7334  2017-05-31         north_druid_hillsdekalbga                   222.0
# 6301  2017-05-31                    mayeryavapaiaz                   118.0
# 6579  2017-05-31            mills_riverhendersonnc                   141.0
# 8188  2017-05-31      pismo_beachsan_luis_obispoca                   502.0
# 7665  2017-05-31                ooltewahhamiltontn                    96.0
# 4683  2017-05-31  homestead_meadows_northel_pasotx                    78.0
# 1117  2017-05-31                  brightontiptontn                    75.0
# 5434  2017-05-31                   lakebaypiercewa                   188.0
# 4768  2017-05-31                    hubertonslownc                    92.0
# 6919  2017-05-31             mountain_viewhawaiihi                   178.0
#
#        Year_x  Month_x                   City_x         County_x State_x  \
# 5240     2017        5               Kingsville          Kleberg      TX
# 6370     2017        5                   Mebane         Alamance      NC
# 5704     2017        5                Limestone       Washington      TN
# 4082     2017        5               Green Tree        Allegheny      PA
# 10865    2017        5                 Tuckahoe      Westchester      NY
# 7971     2017        5                   Payson             Utah      UT
# 6904     2017        5             Mount Vernon      Westchester      NY
# 10550    2017        5           Town of Groton       New London      CT
# 3037     2017        5           Elizabethville          Dauphin      PA
# 5026     2017        5                   Jerome           Jerome      ID
# 1381     2017        5                  Cameron            Milam      TX
# 198      2017        5                  Andover           Butler      KS
# 6733     2017        5               Montgomery          Chatham      GA
# 11922    2017        5             Wood Village        Multnomah      OR
# 8328     2017        5              Poplarville      Pearl River      MS
# 9164     2017        5             San Clemente           Orange      CA
# 6758     2017        5                 Monument          El Paso      CO
# 7417     2017        5              North Utica         La Salle      IL
# 1048     2017        5                    Brant             Erie      NY
# 4529     2017        5                 Hesperia   San Bernardino      CA
# 3739     2017        5           Garden Prairie            Boone      IL
# 6112     2017        5               Manchester         Hartford      CT
# 9100     2017        5          Saint Paul Park       Washington      MN
# 6244     2017        5               Marshfield             Wood      WI
# 1222     2017        5                  Buckeye         Maricopa      AZ
# 5701     2017        5                 Limerick       Montgomery      PA
# 1052     2017        5                Bratenahl         Cuyahoga      OH
# 3221     2017        5                Ewa Beach         Honolulu      HI
# 7932     2017        5              Parsonsburg         Wicomico      MD
# 9607     2017        5               Smithville           Dekalb      TN
# ...       ...      ...                      ...              ...     ...
# 4444     2017        5         Hazel Dell South            Clark      WA
# 8722     2017        5                     Riga          Lenawee      MI
# 5821     2017        5                     Lodi           Bergen      NJ
# 6524     2017        5                  Midland          Midland      TX
# 1148     2017        5                  Bronson             Levy      FL
# 11418    2017        5     Weeki Wachee Gardens         Hernando      FL
# 7537     2017        5                  Oakland           Orange      FL
# 7143     2017        5          New Marlborough        Berkshire      MA
# 4914     2017        5                 Irondale        Jefferson      AL
# 3694     2017        5                  Gadsden         Richland      SC
# 11506    2017        5          West Friendship           Howard      MD
# 3748     2017        5                  Gardner          Johnson      KS
# 10562    2017        5         Town of Herkimer         Herkimer      NY
# 4354     2017        5                 Harrison          Calumet      WI
# 11090    2017        5          Vernon Township           Sussex      NJ
# 9463     2017        5                   Shelby           Shelby      AL
# 3254     2017        5       Fairfield Township     Westmoreland      PA
# 10058    2017        5               Sugar City          Madison      ID
# 2194     2017        5                   Corona        Riverside      CA
# 6613     2017        5            Mineral Point       Washington      MO
# 7334     2017        5        North Druid Hills           Dekalb      GA
# 6301     2017        5                    Mayer          Yavapai      AZ
# 6579     2017        5              Mills River        Henderson      NC
# 8188     2017        5              Pismo Beach  San Luis Obispo      CA
# 7665     2017        5                 Ooltewah         Hamilton      TN
# 4683     2017        5  Homestead Meadows North          El Paso      TX
# 1117     2017        5                 Brighton           Tipton      TN
# 5434     2017        5                  Lakebay           Pierce      WA
# 4768     2017        5                   Hubert           Onslow      NC
# 6919     2017        5            Mountain View           Hawaii      HI
#
#           Date_y  ZHVIPerSqft_AllHomes_y  Year_y  Month_y  \
# 5240  2012-05-31                    61.0    2012        5
# 6370  2012-05-31                    91.0    2012        5
# 5704  2012-05-31                    69.0    2012        5
# 4082  2012-05-31                    99.0    2012        5
# 10865 2012-05-31                   267.0    2012        5
# 7971  2012-05-31                   104.0    2012        5
# 6904  2012-05-31                   195.0    2012        5
# 10550 2012-05-31                   135.0    2012        5
# 3037  2012-05-31                    60.0    2012        5
# 5026  2012-05-31                    71.0    2012        5
# 1381  2012-05-31                    41.0    2012        5
# 198   2012-05-31                    70.0    2012        5
# 6733  2012-05-31                   101.0    2012        5
# 11922 2012-05-31                   113.0    2012        5
# 8328  2012-05-31                    65.0    2012        5
# 9164  2012-05-31                   302.0    2012        5
# 6758  2012-05-31                   113.0    2012        5
# 7417  2012-05-31                    93.0    2012        5
# 1048  2012-05-31                    82.0    2012        5
# 4529  2012-05-31                    67.0    2012        5
# 3739  2012-05-31                    82.0    2012        5
# 6112  2012-05-31                   122.0    2012        5
# 9100  2012-05-31                    86.0    2012        5
# 6244  2012-05-31                    70.0    2012        5
# 1222  2012-05-31                    56.0    2012        5
# 5701  2012-05-31                   126.0    2012        5
# 1052  2012-05-31                    89.0    2012        5
# 3221  2012-05-31                   300.0    2012        5
# 7932  2012-05-31                    93.0    2012        5
# 9607  2012-05-31                    55.0    2012        5
# ...          ...                     ...     ...      ...
# 4444  2012-05-31                   113.0    2012        5
# 8722  2012-05-31                    54.0    2012        5
# 5821  2012-05-31                   189.0    2012        5
# 6524  2012-05-31                    81.0    2012        5
# 1148  2012-05-31                    52.0    2012        5
# 11418 2012-05-31                   106.0    2012        5
# 7537  2012-05-31                    84.0    2012        5
# 7143  2012-05-31                   184.0    2012        5
# 4914  2012-05-31                    79.0    2012        5
# 3694  2012-05-31                    56.0    2012        5
# 11506 2012-05-31                   206.0    2012        5
# 3748  2012-05-31                   107.0    2012        5
# 10562 2012-05-31                    49.0    2012        5
# 4354  2012-05-31                    88.0    2012        5
# 11090 2012-05-31                   125.0    2012        5
# 9463  2012-05-31                   120.0    2012        5
# 3254  2012-05-31                    87.0    2012        5
# 10058 2012-05-31                    70.0    2012        5
# 2194  2012-05-31                   149.0    2012        5
# 6613  2012-05-31                    73.0    2012        5
# 7334  2012-05-31                   142.0    2012        5
# 6301  2012-05-31                    64.0    2012        5
# 6579  2012-05-31                   102.0    2012        5
# 8188  2012-05-31                   326.0    2012        5
# 7665  2012-05-31                    83.0    2012        5
# 4683  2012-05-31                    78.0    2012        5
# 1117  2012-05-31                    67.0    2012        5
# 5434  2012-05-31                   139.0    2012        5
# 4768  2012-05-31                   100.0    2012        5
# 6919  2012-05-31                   121.0    2012        5
#
#                         City_y         County_y State_y    Dif Label  \
# 5240                Kingsville          Kleberg      TX    2.0    no
# 6370                    Mebane         Alamance      NC   13.0    no
# 5704                 Limestone       Washington      TN   13.0    no
# 4082                Green Tree        Allegheny      PA   21.0    no
# 10865                 Tuckahoe      Westchester      NY   62.0    no
# 7971                    Payson             Utah      UT   56.0    no
# 6904              Mount Vernon      Westchester      NY   36.0    no
# 10550           Town of Groton       New London      CT   12.0    no
# 3037            Elizabethville          Dauphin      PA   15.0    no
# 5026                    Jerome           Jerome      ID   22.0    no
# 1381                   Cameron            Milam      TX   15.0    no
# 198                    Andover           Butler      KS    7.0    no
# 6733                Montgomery          Chatham      GA   22.0    no
# 11922             Wood Village        Multnomah      OR   69.0    no
# 8328               Poplarville      Pearl River      MS    5.0    no
# 9164              San Clemente           Orange      CA  160.0   yes
# 6758                  Monument          El Paso      CO   33.0    no
# 7417               North Utica         La Salle      IL    6.0    no
# 1048                     Brant             Erie      NY   23.0    no
# 4529                  Hesperia   San Bernardino      CA   75.0    no
# 3739            Garden Prairie            Boone      IL   16.0    no
# 6112                Manchester         Hartford      CT    1.0    no
# 9100           Saint Paul Park       Washington      MN   39.0    no
# 6244                Marshfield             Wood      WI    8.0    no
# 1222                   Buckeye         Maricopa      AZ   51.0    no
# 5701                  Limerick       Montgomery      PA   17.0    no
# 1052                 Bratenahl         Cuyahoga      OH   20.0    no
# 3221                 Ewa Beach         Honolulu      HI  125.0   yes
# 7932               Parsonsburg         Wicomico      MD   11.0    no
# 9607                Smithville           Dekalb      TN   19.0    no
# ...                        ...              ...     ...    ...   ...
# 4444          Hazel Dell South            Clark      WA   77.0    no
# 8722                      Riga          Lenawee      MI   20.0    no
# 5821                      Lodi           Bergen      NJ   34.0    no
# 6524                   Midland          Midland      TX   26.0    no
# 1148                   Bronson             Levy      FL   23.0    no
# 11418     Weeki Wachee Gardens         Hernando      FL   45.0    no
# 7537                   Oakland           Orange      FL   41.0    no
# 7143           New Marlborough        Berkshire      MA    1.0    no
# 4914                  Irondale        Jefferson      AL    9.0    no
# 3694                   Gadsden         Richland      SC    9.0    no
# 11506          West Friendship           Howard      MD   21.0    no
# 3748                   Gardner          Johnson      KS   26.0    no
# 10562         Town of Herkimer         Herkimer      NY    2.0    no
# 4354                  Harrison          Calumet      WI   20.0    no
# 11090          Vernon Township           Sussex      NJ    6.0    no
# 9463                    Shelby           Shelby      AL   18.0    no
# 3254        Fairfield Township     Westmoreland      PA   23.0    no
# 10058               Sugar City          Madison      ID   13.0    no
# 2194                    Corona        Riverside      CA   86.0    no
# 6613             Mineral Point       Washington      MO    8.0    no
# 7334         North Druid Hills           Dekalb      GA   80.0    no
# 6301                     Mayer          Yavapai      AZ   54.0    no
# 6579               Mills River        Henderson      NC   39.0    no
# 8188               Pismo Beach  San Luis Obispo      CA  176.0   yes
# 7665                  Ooltewah         Hamilton      TN   13.0    no
# 4683   Homestead Meadows North          El Paso      TX    0.0    no
# 1117                  Brighton           Tipton      TN    8.0    no
# 5434                   Lakebay           Pierce      WA   49.0    no
# 4768                    Hubert           Onslow      NC   -8.0    no
# 6919             Mountain View           Hawaii      HI   57.0    no
#
#       predicted_nb predicted_nb2
# 5240            no            no
# 6370            no            no
# 5704            no            no
# 4082            no            no
# 10865          yes           yes
# 7971            no            no
# 6904            no            no
# 10550           no            no
# 3037            no            no
# 5026            no            no
# 1381            no            no
# 198             no            no
# 6733            no            no
# 11922           no            no
# 8328            no            no
# 9164           yes           yes
# 6758            no            no
# 7417            no            no
# 1048            no            no
# 4529            no            no
# 3739            no            no
# 6112            no            no
# 9100            no            no
# 6244            no            no
# 1222            no            no
# 5701            no            no
# 1052            no            no
# 3221           yes           yes
# 7932            no            no
# 9607            no            no
# ...            ...           ...
# 4444            no            no
# 8722            no            no
# 5821            no            no
# 6524            no            no
# 1148            no            no
# 11418           no            no
# 7537            no            no
# 7143            no            no
# 4914            no            no
# 3694            no            no
# 11506           no            no
# 3748            no            no
# 10562           no            no
# 4354            no            no
# 11090           no            no
# 9463            no            no
# 3254            no            no
# 10058           no            no
# 2194            no            no
# 6613            no            no
# 7334            no            no
# 6301            no            no
# 6579            no            no
# 8188           yes           yes
# 7665            no            no
# 4683            no            no
# 1117            no            no
# 5434            no            no
# 4768            no            no
# 6919            no            no
#
# [100 rows x 19 columns]

# %%
invest = df_q5B_test.loc[df_q5B_test["predicted_nb2"]=="yes"]

# %%
invest = invest[["City_x","State_x","ZHVIPerSqft_AllHomes_x"]]

# %%
final_data = invest.sort_values(by='ZHVIPerSqft_AllHomes_x')

# %%
final_data.to_csv("Output.csv",encoding='utf-8', index=False)

# %% [markdown]
# **Sample Data**

# %%
sample_data = city_state_data.head(1000)

# %%
sample_data.to_csv("sample_data.csv",encoding='utf-8', index=False)
